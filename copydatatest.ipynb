# %%
from astropy.io import fits

# Path to your FITS file
# fits_file_path = '../../../projects/k-pop/catalogues/galahdr3-apogeedr17.fits'
fits_file_path = 'data/test/combined.fits'
# Open the FITS file
with fits.open(fits_file_path) as hdul:
    # Access the first extension (HDU 1) which contains the table
    data = hdul[1].data
    
    # Extract the 'APOGEE_ID' and 'sobject_id' columns
    apogee_ids = data['APOGEE_ID']
    galah_ids = data['sobject_id']
    # print(data)
    # Print the 'APOGEE_ID' and 'sobject_id' data for the first five entries
    print("Matched IDs:")
    for i in range(3):  # Ensure we don't go out of range if fewer than 5 entries
        print(f"APOGEE ID: {apogee_ids[i]}, GALAH ID: {galah_ids[i]}")

# This script will display the first five pairs of APOGEE and GALAH identifiers.
# Out:
# Matched IDs:
# APOGEE ID: 2M04394779-5753520, GALAH ID: 131118002401015
# APOGEE ID: 2M04390586-5752435, GALAH ID: 131118002401016
# APOGEE ID: 2M04372258-5755132, GALAH ID: 131118002401023

# %%
from astropy.io import fits
import pandas as pd

# Load the FITS file
fits_path = '../../../projects/k-pop/catalogues/galahdr3-apogeedr17.fits'  # Replace with the path to your FITS file
with fits.open(fits_path) as hdul:
    data = hdul[1].data  # Assuming the data of interest is in the first extension

# Convert to a pandas DataFrame
df = pd.DataFrame(data)

# Print the first 5 rows of the DataFrame
print(df.head())
# Out:
#             star_id       sobject_id           APOGEE_ID   GAIAEDR3_SOURCE_ID  \
# 0  04394779-5753520  131118002401015  2M04394779-5753520  4774350796594075008
# 1  04390586-5752435  131118002401016  2M04390586-5752435  4774349937600609664
# 2  04372258-5755132  131118002401023  2M04372258-5755132  4774340797910201984
# 3  04391862-5802387  131118002401025  2M04391862-5802387  4774324614473456640
# 4  04384845-5813280  131118002401038  2M04384845-5813280  4774315852740197376
#
#           RA        DEC
# 0  69.949141 -57.897781
# 1  69.774443 -57.878754
# 2  69.344086 -57.920361
# 3  69.827605 -58.044109
# 4  69.701901 -58.224445

# %%
from astropy.io import fits
import pandas as pd

# Load the FITS file
fits_path = '../../../projects/k-pop/spectra/galah/dr3/1902250027013731.fits'  # Replace with the path to your FITS file
with fits.open(fits_path) as hdul:
    data = hdul[1].data  # Assuming the data of interest is in the first extension

# Convert to a pandas DataFrame
df = pd.DataFrame(data)

# Print the first 5 rows of the DataFrame
print(df.head())
# Out:
#           0
# 0  0.052054
# 1  0.050679
# 2  0.050785
# 3  0.050299
# 4  0.048695

# %%
from astropy.io import fits
from astropy.table import Table

# Path to the original and the new FITS file
original_fits_path = '../../../projects/k-pop/catalogues/galahdr3-apogeedr17.fits'
new_fits_path = 'data/test/combined.fits'

# Open the original FITS file
with fits.open(original_fits_path) as hdul:
    # Access the data in the first extension (HDU 1)
    data = hdul[1].data
    
    # Convert FITS data to an Astropy Table for easier manipulation
    table = Table(data)
    
    # Copy the first five rows
    new_table = table[:100]

    # Create a new HDU from the table
    hdu = fits.BinTableHDU(new_table)

    # Write the new FITS file with only the first five entries
    hdu.writeto(new_fits_path, overwrite=True)

print(f"Created new FITS file with  entries at {new_fits_path}")
# Out:
# Created new FITS file with  entries at data/test/combined.fits

# %%
import os
import shutil
from astropy.io import fits

# Path to the original FITS file
fits_file_path = 'data/test/combined.fits'
# Directory containing the APOGEE FITS files
source_dir = '../../../projects/k-pop/spectra/apogee/dr17'
# Destination directory
dest_dir = 'data/test/apogee/'

# Ensure the destination directory exists
os.makedirs(dest_dir, exist_ok=True)

# Open the FITS file and read APOGEE_IDs
with fits.open(fits_file_path) as hdul:
    apogee_ids = hdul[1].data['APOGEE_ID']

# Copy the first five corresponding FITS files
for apogee_id in apogee_ids:
    src_file_path = os.path.join(source_dir, f'aspcapStar-dr17-{apogee_id.strip()}.fits')
    dest_file_path = os.path.join(dest_dir, f'aspcapStar-dr17-{apogee_id.strip()}.fits')
    # Check if source file exists before copying
    if os.path.exists(src_file_path):
        shutil.copy(src_file_path, dest_file_path)
        print(f'Copied: {src_file_path} to {dest_file_path}')
    else:
        print(f'Source file not found: {src_file_path}')

print("Files have been copied.")
# Out:
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04394779-5753520.fits to data/test/apogee/aspcapStar-dr17-2M04394779-5753520.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04390586-5752435.fits to data/test/apogee/aspcapStar-dr17-2M04390586-5752435.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04372258-5755132.fits to data/test/apogee/aspcapStar-dr17-2M04372258-5755132.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04391862-5802387.fits to data/test/apogee/aspcapStar-dr17-2M04391862-5802387.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04384845-5813280.fits to data/test/apogee/aspcapStar-dr17-2M04384845-5813280.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04373299-5814393.fits to data/test/apogee/aspcapStar-dr17-2M04373299-5814393.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04362390-5807107.fits to data/test/apogee/aspcapStar-dr17-2M04362390-5807107.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04362311-5825430.fits to data/test/apogee/aspcapStar-dr17-2M04362311-5825430.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04362309-5831586.fits to data/test/apogee/aspcapStar-dr17-2M04362309-5831586.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04361896-5833145.fits to data/test/apogee/aspcapStar-dr17-2M04361896-5833145.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04361209-5833162.fits to data/test/apogee/aspcapStar-dr17-2M04361209-5833162.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05273949-5752129.fits to data/test/apogee/aspcapStar-dr17-2M05273949-5752129.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05305052-5754076.fits to data/test/apogee/aspcapStar-dr17-2M05305052-5754076.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05300886-5756494.fits to data/test/apogee/aspcapStar-dr17-2M05300886-5756494.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05284808-5759583.fits to data/test/apogee/aspcapStar-dr17-2M05284808-5759583.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05311779-5810048.fits to data/test/apogee/aspcapStar-dr17-2M05311779-5810048.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05315649-5812265.fits to data/test/apogee/aspcapStar-dr17-2M05315649-5812265.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05321481-5814597.fits to data/test/apogee/aspcapStar-dr17-2M05321481-5814597.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05311201-5813034.fits to data/test/apogee/aspcapStar-dr17-2M05311201-5813034.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05284065-5800105.fits to data/test/apogee/aspcapStar-dr17-2M05284065-5800105.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05312655-5823570.fits to data/test/apogee/aspcapStar-dr17-2M05312655-5823570.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05302143-5817378.fits to data/test/apogee/aspcapStar-dr17-2M05302143-5817378.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05305203-5828066.fits to data/test/apogee/aspcapStar-dr17-2M05305203-5828066.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05281878-5810200.fits to data/test/apogee/aspcapStar-dr17-2M05281878-5810200.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05304902-5833088.fits to data/test/apogee/aspcapStar-dr17-2M05304902-5833088.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05292291-5823105.fits to data/test/apogee/aspcapStar-dr17-2M05292291-5823105.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M
fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06080111-5759485.fits to data/test/apogee/aspcapStar-dr17-2M06080111-5759485.fits
# Files have been copied.

# %%
import os
import shutil
from astropy.io import fits

# Path to the original FITS file
fits_file_path = 'data/test/combined.fits'
# Directory containing the APOGEE FITS files
source_dir = '../../../projects/k-pop/spectra/galah/dr3'
# Destination directory
dest_dir = 'data/test2/galah'

# Ensure the destination directory exists
os.makedirs(dest_dir, exist_ok=True)

# Open the FITS file and read APOGEE_IDs
with fits.open(fits_file_path) as hdul:
    galah_ids = hdul[1].data['sobject_id']

# Copy the first corresponding FITS file that is found
for galah_id in galah_ids:
    file_found = False
    for i in range(1, 5): 
        src_file_path = os.path.join(source_dir, f'{galah_id}{i}.fits')
        dest_file_path = os.path.join(dest_dir, f'{galah_id}{i}.fits')
        if os.path.exists(src_file_path):
            shutil.copy(src_file_path, dest_file_path)
            print(f'Copied: {src_file_path} to {dest_file_path}')
  

print("Files have been copied.")
# Out:
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010151.fits to data/test2/galah/1311180024010151.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010152.fits to data/test2/galah/1311180024010152.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010153.fits to data/test2/galah/1311180024010153.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010154.fits to data/test2/galah/1311180024010154.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010161.fits to data/test2/galah/1311180024010161.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010162.fits to data/test2/galah/1311180024010162.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010163.fits to data/test2/galah/1311180024010163.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010164.fits to data/test2/galah/1311180024010164.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010231.fits to data/test2/galah/1311180024010231.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010232.fits to data/test2/galah/1311180024010232.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010233.fits to data/test2/galah/1311180024010233.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010234.fits to data/test2/galah/1311180024010234.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010251.fits to data/test2/galah/1311180024010251.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010252.fits to data/test2/galah/1311180024010252.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010253.fits to data/test2/galah/1311180024010253.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010254.fits to data/test2/galah/1311180024010254.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010381.fits to data/test2/galah/1311180024010381.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010382.fits to data/test2/galah/1311180024010382.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010383.fits to data/test2/galah/1311180024010383.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010384.fits to data/test2/galah/1311180024010384.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010461.fits to data/test2/galah/1311180024010461.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010462.fits to data/test2/galah/1311180024010462.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010463.fits to data/test2/galah/1311180024010463.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010464.fits to data/test2/galah/1311180024010464.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010471.fits to data/test2/galah/1311180024010471.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010472.fits to data/test2/galah/1311180024010472.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010473.fits to data/test2/galah/1311180024010473.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010474.fits to data/test2/galah/1311180024010474.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010631.fits to data/test2/galah/1311180024010631.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010632.fits to data/test2/galah/1311180024010632.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010633.fits to data/test2/galah/1311180024010633.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010634.fits to data/test2/galah/1311180024010634.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010661.fits to data/test2/galah/1311180024010661.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010662.fits to data/test2/galah/1311180024010662.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010663.fits to data/test2/galah/1311180024010663.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010664.fits to data/test2/galah/1311180024010664.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010681.fits to data/test2/galah/1311180024010681.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010682.fits to data/test2/galah/1311180024010682.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010683.fits to data/test2/galah/1311180024010683.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010684.fits to data/test2/galah/1311180024010684.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010691.fits to data/test2/galah/1311180024010691.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010692.fits to data/test2/galah/1311180024010692.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010693.fits to data/test2/galah/1311180024010693.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010694.fits to data/test2/galah/1311180024010694.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010031.fits to data/test2/galah/1311180029010031.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010032.fits to data/test2/galah/1311180029010032.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010033.fits to data/test2/galah/1311180029010033.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010034.fits to data/test2/galah/1311180029010034.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010041.fits to data/test2/galah/1311180029010041.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010042.fits to data/test2/galah/1311180029010042.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010043.fits to data/test2/galah/1311180029010043.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010044.fits to data/test2/galah/1311180029010044.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010091.fits to data/test2/galah/1311180029010091.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010092.fits to data/test2/galah/1311180029010092.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010093.fits to data/test2/galah/1311180029010093.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029
fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011283.fits to data/test2/galah/1311180034011283.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011284.fits to data/test2/galah/1311180034011284.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011341.fits to data/test2/galah/1311180034011341.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011342.fits to data/test2/galah/1311180034011342.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011343.fits to data/test2/galah/1311180034011343.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011344.fits to data/test2/galah/1311180034011344.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011461.fits to data/test2/galah/1311180034011461.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011462.fits to data/test2/galah/1311180034011462.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011463.fits to data/test2/galah/1311180034011463.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011464.fits to data/test2/galah/1311180034011464.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011531.fits to data/test2/galah/1311180034011531.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011532.fits to data/test2/galah/1311180034011532.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011533.fits to data/test2/galah/1311180034011533.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011534.fits to data/test2/galah/1311180034011534.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011591.fits to data/test2/galah/1311180034011591.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011592.fits to data/test2/galah/1311180034011592.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011593.fits to data/test2/galah/1311180034011593.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011594.fits to data/test2/galah/1311180034011594.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011841.fits to data/test2/galah/1311180034011841.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011842.fits to data/test2/galah/1311180034011842.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011843.fits to data/test2/galah/1311180034011843.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011844.fits to data/test2/galah/1311180034011844.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011901.fits to data/test2/galah/1311180034011901.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011902.fits to data/test2/galah/1311180034011902.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011903.fits to data/test2/galah/1311180034011903.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011904.fits to data/test2/galah/1311180034011904.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011971.fits to data/test2/galah/1311180034011971.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011972.fits to data/test2/galah/1311180034011972.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011973.fits to data/test2/galah/1311180034011973.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011974.fits to data/test2/galah/1311180034011974.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012051.fits to data/test2/galah/1311180034012051.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012052.fits to data/test2/galah/1311180034012052.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012053.fits to data/test2/galah/1311180034012053.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012054.fits to data/test2/galah/1311180034012054.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012071.fits to data/test2/galah/1311180034012071.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012072.fits to data/test2/galah/1311180034012072.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012073.fits to data/test2/galah/1311180034012073.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012074.fits to data/test2/galah/1311180034012074.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012311.fits to data/test2/galah/1311180034012311.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012312.fits to data/test2/galah/1311180034012312.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012313.fits to data/test2/galah/1311180034012313.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012314.fits to data/test2/galah/1311180034012314.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012321.fits to data/test2/galah/1311180034012321.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012322.fits to data/test2/galah/1311180034012322.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012323.fits to data/test2/galah/1311180034012323.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012324.fits to data/test2/galah/1311180034012324.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012431.fits to data/test2/galah/1311180034012431.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012432.fits to data/test2/galah/1311180034012432.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012433.fits to data/test2/galah/1311180034012433.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012434.fits to data/test2/galah/1311180034012434.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012561.fits to data/test2/galah/1311180034012561.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012562.fits to data/test2/galah/1311180034012562.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012563.fits to data/test2/galah/1311180034012563.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012564.fits to data/test2/galah/1311180034012564.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012621.fits to data/test2/galah/1311180034012621.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012622.fits to data/test2/galah/1311180034012622.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012623.fits to data/test2/galah/1311180034012623.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012624.fits to data/test2/galah/1311180034012624.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012661.fits to data/test2/galah/1311180034012661.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012662.fits to data/test2/galah/1311180034012662.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012663.fits to data/test2/galah/1311180034012663.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012664.fits to data/test2/galah/1311180034012664.fits
# Files have been copied.

# %%
import os
import shutil
import random
from astropy.io import fits

# Path to the original FITS file
fits_file_path = 'data/test/combined.fits'
# Directory containing the GALAH FITS files
source_dir = '../../../projects/k-pop/spectra/galah/dr3'
# Destination directory
dest_dir = 'data/test2/galah'
# Ensure the destination directory exists
os.makedirs(dest_dir, exist_ok=True)

# Open the FITS file and read GALAH IDs
with fits.open(fits_file_path) as hdul:
    galah_ids = set(hdul[1].data['sobject_id'])

# Get all FITS files in the source directory
all_files = [f for f in os.listdir(source_dir) if f.endswith('.fits')]

# Filter files that are not in galah_ids
files_not_in_list = [f[:15] for f in all_files if f[:15] not in galah_ids]

# Randomly select 200 files (or all if less than 200)
files_to_copy = random.sample(files_not_in_list, min(200, len(files_not_in_list)))

# Prepare to copy all files that start with any of the selected filenames
files_to_copy_full = [f for f in all_files if any(f.startswith(prefix) for prefix in files_to_copy)]

# Copy the selected files
for file_name in files_to_copy_full:
    src_file_path = os.path.join(source_dir, file_name)
    dest_file_path = os.path.join(dest_dir, file_name)
    shutil.copy(src_file_path, dest_file_path)
    print(f'Copied: {src_file_path} to {dest_file_path}')

print(f"Copied {len(files_to_copy_full)} files that start with selected filenames.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 29
#      26 files_to_copy = random.sample(files_not_in_list, min(200, len(files_not_in_list)))
#      28 # Prepare to copy all files that start with any of the selected filenames
# ---> 29 files_to_copy_full = [f for f in all_files if any(f.startswith(prefix) for prefix in files_to_copy)]
#      31 # Copy the selected files
#      32 for file_name in files_to_copy_full:
#
# Cell In[6], line 29, in <listcomp>(.0)
#      26 files_to_copy = random.sample(files_not_in_list, min(200, len(files_not_in_list)))
#      28 # Prepare to copy all files that start with any of the selected filenames
# ---> 29 files_to_copy_full = [f for f in all_files if any(f.startswith(prefix) for prefix in files_to_copy)]
#      31 # Copy the selected files
#      32 for file_name in files_to_copy_full:
#
# Cell In[6], line 29, in <genexpr>(.0)
#      26 files_to_copy = random.sample(files_not_in_list, min(200, len(files_not_in_list)))
#      28 # Prepare to copy all files that start with any of the selected filenames
# ---> 29 files_to_copy_full = [f for f in all_files if any(f.startswith(prefix) for prefix in files_to_copy)]
#      31 # Copy the selected files
#      32 for file_name in files_to_copy_full:
#
# KeyboardInterrupt:

# %%
import os
import shutil
import random
from astropy.io import fits

# Paths
fits_file_path = 'data/test/combined.fits'
source_dir = '../../../projects/k-pop/spectra/galah/dr3'
dest_dir = 'data/test2/galah'

# Make sure the destination directory exists
os.makedirs(dest_dir, exist_ok=True)

# Read the existing GALAH_IDs from the combined.fits file
with fits.open(fits_file_path) as hdul:
    existing_ids = set(hdul[1].data['sobject_id'])

# Function to get a batch of file names
def get_file_batch(directory, batch_size=1500):
    for i, filename in enumerate(os.listdir(directory)):
        if i % batch_size == 0 and i > 0:
            yield
        if filename.endswith('.fits'):
            yield filename

# Set to store unique GALAH IDs
new_ids = set()

# Process files in batches
for batch in get_file_batch(source_dir):
    if batch is None:  # This is just a yield to allow for breaking the loop
        if len(new_ids) >= 200:
            break
        continue
    
    galah_id = batch[:-5]  # Remove '.fits' and last character (channel number)
    if galah_id not in existing_ids:
        new_ids.add(galah_id)
    
    if len(new_ids) >= 200:
        break

# Randomly select 200 IDs (or all if less than 200 available)
selected_ids = random.sample(list(new_ids), min(200, len(new_ids)))

# Copy files for selected IDs
copied_count = 0
for galah_id in selected_ids:
    for i in range(1, 5):  # Channels 1 to 4
        source_file = os.path.join(source_dir, f"{galah_id}{i}.fits")
        if os.path.exists(source_file):
            dest_file = os.path.join(dest_dir, f"{galah_id}{i}.fits")
            shutil.copy2(source_file, dest_file)
            copied_count += 1

print(f"Copied {copied_count} files for {len(selected_ids)} unique GALAH IDs.")
# Out:
# Copied 0 files for 200 unique GALAH IDs.

# %%
import os
import shutil
from astropy.io import fits

# Paths
fits_file_path = 'data/test/combined.fits'
source_dir = '../../../projects/k-pop/spectra/apogee/dr17'
dest_dir = 'data/test2/apogee/'

# Ensure the destination directory exists
os.makedirs(dest_dir, exist_ok=True)

# Read the existing APOGEE_IDs from the combined.fits file to ensure they are not copied
existing_ids = set()
with fits.open(fits_file_path) as hdul:
    if 'APOGEE_ID' in hdul[1].columns.names:
        existing_ids = set(hdul[1].data['APOGEE_ID'])

# Initialize a counter for the number of files copied
file_count = 0

# Iterate through potential APOGEE_IDs and copy the first matching file
for root, dirs, files in os.walk(source_dir):
    for file in files:
        if file.endswith('.fits'):
            apogee_id = file.split('-')[-1].split('.')[0]  # Extract the APOGEE_ID from the filename
            # Check if the APOGEE_ID is not in the existing IDs and we have not reached 200 files yet
            if apogee_id not in existing_ids and file_count < 200:
                src_file_path = os.path.join(root, file)
                dest_file_path = os.path.join(dest_dir, file)  # Use original filename in the destination
                shutil.copy(src_file_path, dest_file_path)
                print(f'Copied: {src_file_path} to {dest_file_path}')
                file_count += 1
                existing_ids.add(apogee_id)  # Ensure no further files with this APOGEE_ID are copied
                # Break if 200 files have been copied
                if file_count >= 200:
                    break
    if file_count >= 200:
        break

print(f"Files copied: {file_count}")

# %%
import os
import shutil
import random
import re

def copy_files_based_on_galah_id(source_dir, destination_dir, num_samples=300):
    # Use a reservoir sampling algorithm to randomly select files from a large directory
    selected_files = []
    for i, file_name in enumerate(os.listdir(source_dir)):
        if os.path.isfile(os.path.join(source_dir, file_name)):
            if i < num_samples:
                selected_files.append(file_name)
            else:
                r = random.randint(0, i)
                if r < num_samples:
                    selected_files[r] = file_name

    # Now find and copy files with the matching galah_id
    for file in selected_files:
        # Extract the first 15 digits from the filename
        match = re.match(r"(\d{15})", file)
        if match:
            galah_id = match.group(1)
            # Copy files starting with this galah_id
            for f in os.listdir(source_dir):
                if f.startswith(galah_id):
                    src = os.path.join(source_dir, f)
                    dest = os.path.join(destination_dir, f)
                    shutil.copy2(src, dest)
                    print(f"Copied {f} to {destination_dir}")



if __name__ == "__main__":
    source_dir = '../../../projects/k-pop/spectra/galah/dr3'
    # Destination directory
    dest_dir = 'data/test2/galah'
    copy_files_based_on_galah_id(source_dir, dest_dir)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 38
#      36 # Destination directory
#      37 dest_dir = 'data/test2/galah'
# ---> 38 copy_files_based_on_galah_id(source_dir, dest_dir)
#
# Cell In[10], line 9, in copy_files_based_on_galah_id(source_dir, destination_dir, num_samples)
#       6 def copy_files_based_on_galah_id(source_dir, destination_dir, num_samples=300):
#       7     # Use a reservoir sampling algorithm to randomly select files from a large directory
#       8     selected_files = []
# ----> 9     for i, file_name in enumerate(os.listdir(source_dir)):
#      10         if os.path.isfile(os.path.join(source_dir, file_name)):
#      11             if i < num_samples:
#
# KeyboardInterrupt:
