# %%
from astropy.io import fits

# Path to your FITS file
# fits_file_path = '../../../projects/k-pop/catalogues/galahdr3-apogeedr17.fits'
fits_file_path = 'data/test/combined.fits'
# Open the FITS file
with fits.open(fits_file_path) as hdul:
    # Access the first extension (HDU 1) which contains the table
    data = hdul[1].data
    
    # Extract the 'APOGEE_ID' and 'sobject_id' columns
    apogee_ids = data['APOGEE_ID']
    galah_ids = data['sobject_id']
    # print(data)
    # Print the 'APOGEE_ID' and 'sobject_id' data for the first five entries
    print("Matched IDs:")
    for i in range(3):  # Ensure we don't go out of range if fewer than 5 entries
        print(f"APOGEE ID: {apogee_ids[i]}, GALAH ID: {galah_ids[i]}")

# This script will display the first five pairs of APOGEE and GALAH identifiers.
# Out:
# Matched IDs:
# APOGEE ID: 2M04394779-5753520, GALAH ID: 131118002401015
# APOGEE ID: 2M04390586-5752435, GALAH ID: 131118002401016
# APOGEE ID: 2M04372258-5755132, GALAH ID: 131118002401023

# %%
from astropy.io import fits
import pandas as pd

# Load the FITS file
fits_path = '../../../projects/k-pop/catalogues/galahdr3-apogeedr17.fits'  # Replace with the path to your FITS file
with fits.open(fits_path) as hdul:
    data = hdul[1].data  # Assuming the data of interest is in the first extension

# Convert to a pandas DataFrame
df = pd.DataFrame(data)

# Print the first 5 rows of the DataFrame
print(df.head())
# Out:
#             star_id       sobject_id           APOGEE_ID   GAIAEDR3_SOURCE_ID  \
# 0  04394779-5753520  131118002401015  2M04394779-5753520  4774350796594075008
# 1  04390586-5752435  131118002401016  2M04390586-5752435  4774349937600609664
# 2  04372258-5755132  131118002401023  2M04372258-5755132  4774340797910201984
# 3  04391862-5802387  131118002401025  2M04391862-5802387  4774324614473456640
# 4  04384845-5813280  131118002401038  2M04384845-5813280  4774315852740197376
#
#           RA        DEC
# 0  69.949141 -57.897781
# 1  69.774443 -57.878754
# 2  69.344086 -57.920361
# 3  69.827605 -58.044109
# 4  69.701901 -58.224445

# %%
from astropy.io import fits
import pandas as pd

# Load the FITS file
fits_path = '../../../projects/k-pop/spectra/galah/dr3/1902250027013731.fits'  # Replace with the path to your FITS file
with fits.open(fits_path) as hdul:
    data = hdul[1].data  # Assuming the data of interest is in the first extension

# Convert to a pandas DataFrame
df = pd.DataFrame(data)

# Print the first 5 rows of the DataFrame
print(df.head())
# Out:
#           0
# 0  0.052054
# 1  0.050679
# 2  0.050785
# 3  0.050299
# 4  0.048695

# %%
from astropy.io import fits
from astropy.table import Table

# Path to the original and the new FITS file
original_fits_path = '../../../projects/k-pop/catalogues/galahdr3-apogeedr17.fits'
new_fits_path = 'data/test/combined.fits'

# Open the original FITS file
with fits.open(original_fits_path) as hdul:
    # Access the data in the first extension (HDU 1)
    data = hdul[1].data
    
    # Convert FITS data to an Astropy Table for easier manipulation
    table = Table(data)
    
    # Copy the first five rows
    new_table = table[:100]

    # Create a new HDU from the table
    hdu = fits.BinTableHDU(new_table)

    # Write the new FITS file with only the first five entries
    hdu.writeto(new_fits_path, overwrite=True)

print(f"Created new FITS file with  entries at {new_fits_path}")
# Out:
# Created new FITS file with  entries at data/test/combined.fits

# %%
import os
import shutil
from astropy.io import fits

# Path to the original FITS file
fits_file_path = 'data/test/combined.fits'
# Directory containing the APOGEE FITS files
source_dir = '../../../projects/k-pop/spectra/apogee/dr17'
# Destination directory
dest_dir = 'data/test/apogee/'

# Ensure the destination directory exists
os.makedirs(dest_dir, exist_ok=True)

# Open the FITS file and read APOGEE_IDs
with fits.open(fits_file_path) as hdul:
    apogee_ids = hdul[1].data['APOGEE_ID']

# Copy the first five corresponding FITS files
for apogee_id in apogee_ids:
    src_file_path = os.path.join(source_dir, f'aspcapStar-dr17-{apogee_id.strip()}.fits')
    dest_file_path = os.path.join(dest_dir, f'aspcapStar-dr17-{apogee_id.strip()}.fits')
    # Check if source file exists before copying
    if os.path.exists(src_file_path):
        shutil.copy(src_file_path, dest_file_path)
        print(f'Copied: {src_file_path} to {dest_file_path}')
    else:
        print(f'Source file not found: {src_file_path}')

print("Files have been copied.")
# Out:
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04394779-5753520.fits to data/test/apogee/aspcapStar-dr17-2M04394779-5753520.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04390586-5752435.fits to data/test/apogee/aspcapStar-dr17-2M04390586-5752435.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04372258-5755132.fits to data/test/apogee/aspcapStar-dr17-2M04372258-5755132.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04391862-5802387.fits to data/test/apogee/aspcapStar-dr17-2M04391862-5802387.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04384845-5813280.fits to data/test/apogee/aspcapStar-dr17-2M04384845-5813280.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04373299-5814393.fits to data/test/apogee/aspcapStar-dr17-2M04373299-5814393.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04362390-5807107.fits to data/test/apogee/aspcapStar-dr17-2M04362390-5807107.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04362311-5825430.fits to data/test/apogee/aspcapStar-dr17-2M04362311-5825430.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04362309-5831586.fits to data/test/apogee/aspcapStar-dr17-2M04362309-5831586.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04361896-5833145.fits to data/test/apogee/aspcapStar-dr17-2M04361896-5833145.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04361209-5833162.fits to data/test/apogee/aspcapStar-dr17-2M04361209-5833162.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05273949-5752129.fits to data/test/apogee/aspcapStar-dr17-2M05273949-5752129.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05305052-5754076.fits to data/test/apogee/aspcapStar-dr17-2M05305052-5754076.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05300886-5756494.fits to data/test/apogee/aspcapStar-dr17-2M05300886-5756494.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05284808-5759583.fits to data/test/apogee/aspcapStar-dr17-2M05284808-5759583.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05311779-5810048.fits to data/test/apogee/aspcapStar-dr17-2M05311779-5810048.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05315649-5812265.fits to data/test/apogee/aspcapStar-dr17-2M05315649-5812265.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05321481-5814597.fits to data/test/apogee/aspcapStar-dr17-2M05321481-5814597.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05311201-5813034.fits to data/test/apogee/aspcapStar-dr17-2M05311201-5813034.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05284065-5800105.fits to data/test/apogee/aspcapStar-dr17-2M05284065-5800105.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05312655-5823570.fits to data/test/apogee/aspcapStar-dr17-2M05312655-5823570.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05302143-5817378.fits to data/test/apogee/aspcapStar-dr17-2M05302143-5817378.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05305203-5828066.fits to data/test/apogee/aspcapStar-dr17-2M05305203-5828066.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05281878-5810200.fits to data/test/apogee/aspcapStar-dr17-2M05281878-5810200.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05304902-5833088.fits to data/test/apogee/aspcapStar-dr17-2M05304902-5833088.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05292291-5823105.fits to data/test/apogee/aspcapStar-dr17-2M05292291-5823105.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05303082-5836070.fits to data/test/apogee/aspcapStar-dr17-2M05303082-5836070.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05281105-5820014.fits to data/test/apogee/aspcapStar-dr17-2M05281105-5820014.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05293429-5840415.fits to data/test/apogee/aspcapStar-dr17-2M05293429-5840415.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05265057-5808486.fits to data/test/apogee/aspcapStar-dr17-2M05265057-5808486.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05283408-5835033.fits to data/test/apogee/aspcapStar-dr17-2M05283408-5835033.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05272462-5828096.fits to data/test/apogee/aspcapStar-dr17-2M05272462-5828096.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05272745-5834527.fits to data/test/apogee/aspcapStar-dr17-2M05272745-5834527.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05270963-5831134.fits to data/test/apogee/aspcapStar-dr17-2M05270963-5831134.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05262478-5815437.fits to data/test/apogee/aspcapStar-dr17-2M05262478-5815437.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05254955-5841349.fits to data/test/apogee/aspcapStar-dr17-2M05254955-5841349.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05253617-5822147.fits to data/test/apogee/aspcapStar-dr17-2M05253617-5822147.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05251069-5817030.fits to data/test/apogee/aspcapStar-dr17-2M05251069-5817030.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05244788-5821374.fits to data/test/apogee/aspcapStar-dr17-2M05244788-5821374.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05253734-5753187.fits to data/test/apogee/aspcapStar-dr17-2M05253734-5753187.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05222215-5759497.fits to data/test/apogee/aspcapStar-dr17-2M05222215-5759497.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05194758-5750387.fits to data/test/apogee/aspcapStar-dr17-2M05194758-5750387.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05181529-5745575.fits to data/test/apogee/aspcapStar-dr17-2M05181529-5745575.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05193941-5745470.fits to data/test/apogee/aspcapStar-dr17-2M05193941-5745470.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05225195-5744595.fits to data/test/apogee/aspcapStar-dr17-2M05225195-5744595.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05242936-5748522.fits to data/test/apogee/aspcapStar-dr17-2M05242936-5748522.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05194953-5718122.fits to data/test/apogee/aspcapStar-dr17-2M05194953-5718122.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05235925-5741041.fits to data/test/apogee/aspcapStar-dr17-2M05235925-5741041.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05201371-5715485.fits to data/test/apogee/aspcapStar-dr17-2M05201371-5715485.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05210544-5710557.fits to data/test/apogee/aspcapStar-dr17-2M05210544-5710557.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05241215-5736375.fits to data/test/apogee/aspcapStar-dr17-2M05241215-5736375.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05241149-5734111.fits to data/test/apogee/aspcapStar-dr17-2M05241149-5734111.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05244663-5740138.fits to data/test/apogee/aspcapStar-dr17-2M05244663-5740138.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05224921-5701469.fits to data/test/apogee/aspcapStar-dr17-2M05224921-5701469.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05253587-5744581.fits to data/test/apogee/aspcapStar-dr17-2M05253587-5744581.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05251877-5715302.fits to data/test/apogee/aspcapStar-dr17-2M05251877-5715302.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05252545-5716484.fits to data/test/apogee/aspcapStar-dr17-2M05252545-5716484.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05251382-5701130.fits to data/test/apogee/aspcapStar-dr17-2M05251382-5701130.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05255070-5717499.fits to data/test/apogee/aspcapStar-dr17-2M05255070-5717499.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05261260-5651592.fits to data/test/apogee/aspcapStar-dr17-2M05261260-5651592.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05254040-5725415.fits to data/test/apogee/aspcapStar-dr17-2M05254040-5725415.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05254758-5737102.fits to data/test/apogee/aspcapStar-dr17-2M05254758-5737102.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05255287-5742253.fits to data/test/apogee/aspcapStar-dr17-2M05255287-5742253.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05263401-5733414.fits to data/test/apogee/aspcapStar-dr17-2M05263401-5733414.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05284025-5703365.fits to data/test/apogee/aspcapStar-dr17-2M05284025-5703365.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05291581-5705292.fits to data/test/apogee/aspcapStar-dr17-2M05291581-5705292.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05274229-5729007.fits to data/test/apogee/aspcapStar-dr17-2M05274229-5729007.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05300490-5707388.fits to data/test/apogee/aspcapStar-dr17-2M05300490-5707388.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05282879-5727519.fits to data/test/apogee/aspcapStar-dr17-2M05282879-5727519.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05295620-5710172.fits to data/test/apogee/aspcapStar-dr17-2M05295620-5710172.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05303930-5707545.fits to data/test/apogee/aspcapStar-dr17-2M05303930-5707545.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05271812-5740017.fits to data/test/apogee/aspcapStar-dr17-2M05271812-5740017.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05273913-5738484.fits to data/test/apogee/aspcapStar-dr17-2M05273913-5738484.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05315176-5728553.fits to data/test/apogee/aspcapStar-dr17-2M05315176-5728553.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05272134-5746248.fits to data/test/apogee/aspcapStar-dr17-2M05272134-5746248.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05300357-5738151.fits to data/test/apogee/aspcapStar-dr17-2M05300357-5738151.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05310107-5743500.fits to data/test/apogee/aspcapStar-dr17-2M05310107-5743500.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06141037-5904459.fits to data/test/apogee/aspcapStar-dr17-2M06141037-5904459.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06124201-5908233.fits to data/test/apogee/aspcapStar-dr17-2M06124201-5908233.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06112784-5938281.fits to data/test/apogee/aspcapStar-dr17-2M06112784-5938281.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06105699-5919255.fits to data/test/apogee/aspcapStar-dr17-2M06105699-5919255.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06101915-5933419.fits to data/test/apogee/aspcapStar-dr17-2M06101915-5933419.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06091423-5944512.fits to data/test/apogee/aspcapStar-dr17-2M06091423-5944512.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06092532-5939117.fits to data/test/apogee/aspcapStar-dr17-2M06092532-5939117.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06094558-5924532.fits to data/test/apogee/aspcapStar-dr17-2M06094558-5924532.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06081410-5935575.fits to data/test/apogee/aspcapStar-dr17-2M06081410-5935575.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06114963-5856581.fits to data/test/apogee/aspcapStar-dr17-2M06114963-5856581.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06103355-5857511.fits to data/test/apogee/aspcapStar-dr17-2M06103355-5857511.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06094072-5902088.fits to data/test/apogee/aspcapStar-dr17-2M06094072-5902088.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06092474-5857170.fits to data/test/apogee/aspcapStar-dr17-2M06092474-5857170.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06042332-5859044.fits to data/test/apogee/aspcapStar-dr17-2M06042332-5859044.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06110865-5849122.fits to data/test/apogee/aspcapStar-dr17-2M06110865-5849122.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06074606-5850112.fits to data/test/apogee/aspcapStar-dr17-2M06074606-5850112.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06103807-5848592.fits to data/test/apogee/aspcapStar-dr17-2M06103807-5848592.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06064735-5829082.fits to data/test/apogee/aspcapStar-dr17-2M06064735-5829082.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06060359-5826429.fits to data/test/apogee/aspcapStar-dr17-2M06060359-5826429.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06084625-5831090.fits to data/test/apogee/aspcapStar-dr17-2M06084625-5831090.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06082161-5818403.fits to data/test/apogee/aspcapStar-dr17-2M06082161-5818403.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06100162-5835400.fits to data/test/apogee/aspcapStar-dr17-2M06100162-5835400.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06080111-5759485.fits to data/test/apogee/aspcapStar-dr17-2M06080111-5759485.fits
# Files have been copied.

# %%
import os
import shutil
from astropy.io import fits

# Path to the original FITS file
fits_file_path = 'data/test/combined.fits'
# Directory containing the APOGEE FITS files
source_dir = '../../../projects/k-pop/spectra/galah/dr3'
# Destination directory
dest_dir = 'data/test/galah'

# Ensure the destination directory exists
os.makedirs(dest_dir, exist_ok=True)

# Open the FITS file and read APOGEE_IDs
with fits.open(fits_file_path) as hdul:
    galah_ids = hdul[1].data['sobject_id']

# Copy the first corresponding FITS file that is found
for galah_id in galah_ids:
    file_found = False
    for i in range(1, 10): 
        src_file_path = os.path.join(source_dir, f'{galah_id}{i}.fits')
        dest_file_path = os.path.join(dest_dir, f'{galah_id}.fits')
        if os.path.exists(src_file_path):
            shutil.copy(src_file_path, dest_file_path)
            print(f'Copied: {src_file_path} to {dest_file_path}')
            file_found = True
            break
    if not file_found:
        print(f'No source file found for: {galah_id} with any suffix.')

print("Files have been copied.")
# Out:
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010151.fits to data/test/galah/131118002401015.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010161.fits to data/test/galah/131118002401016.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010231.fits to data/test/galah/131118002401023.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010251.fits to data/test/galah/131118002401025.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010381.fits to data/test/galah/131118002401038.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010461.fits to data/test/galah/131118002401046.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010471.fits to data/test/galah/131118002401047.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010631.fits to data/test/galah/131118002401063.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010661.fits to data/test/galah/131118002401066.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010681.fits to data/test/galah/131118002401068.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010691.fits to data/test/galah/131118002401069.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010031.fits to data/test/galah/131118002901003.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010041.fits to data/test/galah/131118002901004.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010091.fits to data/test/galah/131118002901009.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010131.fits to data/test/galah/131118002901013.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010231.fits to data/test/galah/131118002901023.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010261.fits to data/test/galah/131118002901026.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010281.fits to data/test/galah/131118002901028.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010311.fits to data/test/galah/131118002901031.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010351.fits to data/test/galah/131118002901035.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010401.fits to data/test/galah/131118002901040.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010411.fits to data/test/galah/131118002901041.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010461.fits to data/test/galah/131118002901046.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010471.fits to data/test/galah/131118002901047.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010491.fits to data/test/galah/131118002901049.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010521.fits to data/test/galah/131118002901052.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010551.fits to data/test/galah/131118002901055.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010611.fits to data/test/galah/131118002901061.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010641.fits to data/test/galah/131118002901064.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010681.fits to data/test/galah/131118002901068.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010691.fits to data/test/galah/131118002901069.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010771.fits to data/test/galah/131118002901077.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010801.fits to data/test/galah/131118002901080.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010811.fits to data/test/galah/131118002901081.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010841.fits to data/test/galah/131118002901084.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010981.fits to data/test/galah/131118002901098.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010991.fits to data/test/galah/131118002901099.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029011071.fits to data/test/galah/131118002901107.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029011131.fits to data/test/galah/131118002901113.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029011151.fits to data/test/galah/131118002901115.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029011771.fits to data/test/galah/131118002901177.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029011991.fits to data/test/galah/131118002901199.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012041.fits to data/test/galah/131118002901204.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012061.fits to data/test/galah/131118002901206.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012161.fits to data/test/galah/131118002901216.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012191.fits to data/test/galah/131118002901219.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012381.fits to data/test/galah/131118002901238.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012401.fits to data/test/galah/131118002901240.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012421.fits to data/test/galah/131118002901242.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012521.fits to data/test/galah/131118002901252.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012581.fits to data/test/galah/131118002901258.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012601.fits to data/test/galah/131118002901260.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012651.fits to data/test/galah/131118002901265.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012711.fits to data/test/galah/131118002901271.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012801.fits to data/test/galah/131118002901280.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012931.fits to data/test/galah/131118002901293.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012951.fits to data/test/galah/131118002901295.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012961.fits to data/test/galah/131118002901296.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013031.fits to data/test/galah/131118002901303.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013041.fits to data/test/galah/131118002901304.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013091.fits to data/test/galah/131118002901309.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013141.fits to data/test/galah/131118002901314.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013161.fits to data/test/galah/131118002901316.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013241.fits to data/test/galah/131118002901324.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013281.fits to data/test/galah/131118002901328.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013351.fits to data/test/galah/131118002901335.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013421.fits to data/test/galah/131118002901342.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013431.fits to data/test/galah/131118002901343.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013451.fits to data/test/galah/131118002901345.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013461.fits to data/test/galah/131118002901346.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013481.fits to data/test/galah/131118002901348.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013551.fits to data/test/galah/131118002901355.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013601.fits to data/test/galah/131118002901360.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013721.fits to data/test/galah/131118002901372.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013741.fits to data/test/galah/131118002901374.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013771.fits to data/test/galah/131118002901377.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013881.fits to data/test/galah/131118002901388.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034010431.fits to data/test/galah/131118003401043.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034010701.fits to data/test/galah/131118003401070.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011031.fits to data/test/galah/131118003401103.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011091.fits to data/test/galah/131118003401109.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011141.fits to data/test/galah/131118003401114.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011221.fits to data/test/galah/131118003401122.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011231.fits to data/test/galah/131118003401123.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011281.fits to data/test/galah/131118003401128.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011341.fits to data/test/galah/131118003401134.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011461.fits to data/test/galah/131118003401146.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011531.fits to data/test/galah/131118003401153.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011591.fits to data/test/galah/131118003401159.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011841.fits to data/test/galah/131118003401184.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011901.fits to data/test/galah/131118003401190.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011971.fits to data/test/galah/131118003401197.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012051.fits to data/test/galah/131118003401205.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012071.fits to data/test/galah/131118003401207.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012311.fits to data/test/galah/131118003401231.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012321.fits to data/test/galah/131118003401232.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012431.fits to data/test/galah/131118003401243.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012561.fits to data/test/galah/131118003401256.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012621.fits to data/test/galah/131118003401262.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012661.fits to data/test/galah/131118003401266.fits
# Files have been copied.

# %%
import os
import shutil
from astropy.io import fits

# Paths
fits_file_path = 'data/test/combined.fits'
source_dir = '../../../projects/k-pop/spectra/galah/dr3'
dest_dir = 'data/test/galah'

# Make sure the destination directory exists
os.makedirs(dest_dir, exist_ok=True)

# Read the existing GALAH_IDs from the combined.fits file to ensure they are not copied
with fits.open(fits_file_path) as hdul:
    existing_ids = set(hdul[1].data['sobject_id'])

# Initialize a counter for the number of files copied
file_count = 0

# Iterate through potential GALAH_IDs and copy the first matching file
for root, dirs, files in os.walk(source_dir):
    for file in files:
        if file.endswith('.fits'):
            galah_id = file.split('.')[0][:-1]  # Remove the last character (number) and the extension
            # Check if the GALAH_ID is not in the existing IDs and we have not reached 200 files yet
            if galah_id not in existing_ids and file_count < 200:
                src_file_path = os.path.join(root, file)
                dest_file_path = os.path.join(dest_dir, f'{galah_id}.fits')
                shutil.copy(src_file_path, dest_file_path)
                print(f'Copied: {src_file_path} to {dest_file_path}')
                file_count += 1
                existing_ids.add(galah_id)  # Ensure no further files with this GALAH_ID are copied
                # Break if 200 files have been copied
                if file_count >= 200:
                    break
    if file_count >= 200:
        break

print(f"Files copied: {file_count}")
# Out:
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06483509-6520109.fits to data/test/apogee/aspcapStar-dr17-2M06483509-6520109.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19455033+3934254.fits to data/test/apogee/aspcapStar-dr17-2M19455033+3934254.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05364343-7600459.fits to data/test/apogee/aspcapStar-dr17-2M05364343-7600459.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M16170533+4207595.fits to data/test/apogee/aspcapStar-dr17-2M16170533+4207595.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M02333009+6128540.fits to data/test/apogee/aspcapStar-dr17-2M02333009+6128540.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-AP00430216+4119487.fits to data/test/apogee/aspcapStar-dr17-AP00430216+4119487.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17383598-2520437.fits to data/test/apogee/aspcapStar-dr17-2M17383598-2520437.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05561286-6458573.fits to data/test/apogee/aspcapStar-dr17-2M05561286-6458573.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M08364426+4343497.fits to data/test/apogee/aspcapStar-dr17-2M08364426+4343497.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M08452451+1222564.fits to data/test/apogee/aspcapStar-dr17-2M08452451+1222564.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M22131053+6237374.fits to data/test/apogee/aspcapStar-dr17-2M22131053+6237374.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M12585388+2630367.fits to data/test/apogee/aspcapStar-dr17-2M12585388+2630367.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03291132+3122570.fits to data/test/apogee/aspcapStar-dr17-2M03291132+3122570.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M16480240+3241036.fits to data/test/apogee/aspcapStar-dr17-2M16480240+3241036.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03130530+4915243.fits to data/test/apogee/aspcapStar-dr17-2M03130530+4915243.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19050661-2058554.fits to data/test/apogee/aspcapStar-dr17-2M19050661-2058554.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03400383+4553266.fits to data/test/apogee/aspcapStar-dr17-2M03400383+4553266.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06321228-7049012.fits to data/test/apogee/aspcapStar-dr17-2M06321228-7049012.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06452898-0500022.fits to data/test/apogee/aspcapStar-dr17-2M06452898-0500022.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M11514811-0030066.fits to data/test/apogee/aspcapStar-dr17-2M11514811-0030066.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M07305670-1159092.fits to data/test/apogee/aspcapStar-dr17-2M07305670-1159092.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06304416-7516481.fits to data/test/apogee/aspcapStar-dr17-2M06304416-7516481.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17535668-1858598.fits to data/test/apogee/aspcapStar-dr17-2M17535668-1858598.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M02222441+4216597.fits to data/test/apogee/aspcapStar-dr17-2M02222441+4216597.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19122005-0029329.fits to data/test/apogee/aspcapStar-dr17-2M19122005-0029329.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M07503562-6440272.fits to data/test/apogee/aspcapStar-dr17-2M07503562-6440272.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M16235301-5527409.fits to data/test/apogee/aspcapStar-dr17-2M16235301-5527409.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M16192925+4349513.fits to data/test/apogee/aspcapStar-dr17-2M16192925+4349513.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M12181260+3654369.fits to data/test/apogee/aspcapStar-dr17-2M12181260+3654369.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M13110694-0223452.fits to data/test/apogee/aspcapStar-dr17-2M13110694-0223452.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19262371+4848086.fits to data/test/apogee/aspcapStar-dr17-2M19262371+4848086.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M10211451+4635128.fits to data/test/apogee/aspcapStar-dr17-2M10211451+4635128.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M18034076-3128489.fits to data/test/apogee/aspcapStar-dr17-2M18034076-3128489.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06074222-7738008.fits to data/test/apogee/aspcapStar-dr17-2M06074222-7738008.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M09401222-3708485.fits to data/test/apogee/aspcapStar-dr17-2M09401222-3708485.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19581477+1839405.fits to data/test/apogee/aspcapStar-dr17-2M19581477+1839405.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M09071941+2741594.fits to data/test/apogee/aspcapStar-dr17-2M09071941+2741594.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17354172-3303389.fits to data/test/apogee/aspcapStar-dr17-2M17354172-3303389.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M13182212+2929075.fits to data/test/apogee/aspcapStar-dr17-2M13182212+2929075.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19121817+2636189.fits to data/test/apogee/aspcapStar-dr17-2M19121817+2636189.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M10342593+0509350.fits to data/test/apogee/aspcapStar-dr17-2M10342593+0509350.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03114538+0014213.fits to data/test/apogee/aspcapStar-dr17-2M03114538+0014213.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M11313755+5248565.fits to data/test/apogee/aspcapStar-dr17-2M11313755+5248565.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19285898+4617550.fits to data/test/apogee/aspcapStar-dr17-2M19285898+4617550.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M01300904+0646314.fits to data/test/apogee/aspcapStar-dr17-2M01300904+0646314.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17000061-2232451.fits to data/test/apogee/aspcapStar-dr17-2M17000061-2232451.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03322024+4557215.fits to data/test/apogee/aspcapStar-dr17-2M03322024+4557215.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M18311104+0241471.fits to data/test/apogee/aspcapStar-dr17-2M18311104+0241471.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06473318-7601465.fits to data/test/apogee/aspcapStar-dr17-2M06473318-7601465.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M01050392+0545419.fits to data/test/apogee/aspcapStar-dr17-2M01050392+0545419.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03380895+1952075.fits to data/test/apogee/aspcapStar-dr17-2M03380895+1952075.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M08070169+5132179.fits to data/test/apogee/aspcapStar-dr17-2M08070169+5132179.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M21284781+5836227.fits to data/test/apogee/aspcapStar-dr17-2M21284781+5836227.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04073684-6745254.fits to data/test/apogee/aspcapStar-dr17-2M04073684-6745254.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M20005939+4442514.fits to data/test/apogee/aspcapStar-dr17-2M20005939+4442514.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M16063154-2335468.fits to data/test/apogee/aspcapStar-dr17-2M16063154-2335468.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M16544215+2021505.fits to data/test/apogee/aspcapStar-dr17-2M16544215+2021505.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19204356+3747019.fits to data/test/apogee/aspcapStar-dr17-2M19204356+3747019.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04122011-6600474.fits to data/test/apogee/aspcapStar-dr17-2M04122011-6600474.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04113035+2739395.fits to data/test/apogee/aspcapStar-dr17-2M04113035+2739395.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M15135297+4121478.fits to data/test/apogee/aspcapStar-dr17-2M15135297+4121478.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03183527+0842049.fits to data/test/apogee/aspcapStar-dr17-2M03183527+0842049.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M09451691+3849236.fits to data/test/apogee/aspcapStar-dr17-2M09451691+3849236.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M14135462+4118182.fits to data/test/apogee/aspcapStar-dr17-2M14135462+4118182.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-AP18090653-3119243.fits to data/test/apogee/aspcapStar-dr17-AP18090653-3119243.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04584489-7059111.fits to data/test/apogee/aspcapStar-dr17-2M04584489-7059111.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M01442843+3612543.fits to data/test/apogee/aspcapStar-dr17-2M01442843+3612543.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M07015373-6308321.fits to data/test/apogee/aspcapStar-dr17-2M07015373-6308321.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M18005522-3030153.fits to data/test/apogee/aspcapStar-dr17-2M18005522-3030153.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17431967-2228435.fits to data/test/apogee/aspcapStar-dr17-2M17431967-2228435.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M22005422-1304309.fits to data/test/apogee/aspcapStar-dr17-2M22005422-1304309.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M08274256+4249501.fits to data/test/apogee/aspcapStar-dr17-2M08274256+4249501.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17594058+6157509.fits to data/test/apogee/aspcapStar-dr17-2M17594058+6157509.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M12123163+4602119.fits to data/test/apogee/aspcapStar-dr17-2M12123163+4602119.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M15191925-4157410.fits to data/test/apogee/aspcapStar-dr17-2M15191925-4157410.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M20232983+1641270.fits to data/test/apogee/aspcapStar-dr17-2M20232983+1641270.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M07374325+4641267.fits to data/test/apogee/aspcapStar-dr17-2M07374325+4641267.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M15580991-2244333.fits to data/test/apogee/aspcapStar-dr17-2M15580991-2244333.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04570669+7219354.fits to data/test/apogee/aspcapStar-dr17-2M04570669+7219354.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19235074+6533399.fits to data/test/apogee/aspcapStar-dr17-2M19235074+6533399.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03544024+2032232.fits to data/test/apogee/aspcapStar-dr17-2M03544024+2032232.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05410634-0810006.fits to data/test/apogee/aspcapStar-dr17-2M05410634-0810006.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M01182926+0701157.fits to data/test/apogee/aspcapStar-dr17-2M01182926+0701157.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M09045109+3229266.fits to data/test/apogee/aspcapStar-dr17-2M09045109+3229266.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05143322+4538260.fits to data/test/apogee/aspcapStar-dr17-2M05143322+4538260.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03293013+6257119.fits to data/test/apogee/aspcapStar-dr17-2M03293013+6257119.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19175572+4424496.fits to data/test/apogee/aspcapStar-dr17-2M19175572+4424496.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17281750-2902266.fits to data/test/apogee/aspcapStar-dr17-2M17281750-2902266.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M02415044-1157536.fits to data/test/apogee/aspcapStar-dr17-2M02415044-1157536.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-AP17523977-2837540.fits to data/test/apogee/aspcapStar-dr17-AP17523977-2837540.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05530209-7116128.fits to data/test/apogee/aspcapStar-dr17-2M05530209-7116128.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M08045911-6900365.fits to data/test/apogee/aspcapStar-dr17-2M08045911-6900365.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04465997+2434299.fits to data/test/apogee/aspcapStar-dr17-2M04465997+2434299.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M10322555+4420439.fits to data/test/apogee/aspcapStar-dr17-2M10322555+4420439.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19034794-1006347.fits to data/test/apogee/aspcapStar-dr17-2M19034794-1006347.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M10482685+1620452.fits to data/test/apogee/aspcapStar-dr17-2M10482685+1620452.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M08183179+3838281.fits to data/test/apogee/aspcapStar-dr17-2M08183179+3838281.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17075252+5737141.fits to data/test/apogee/aspcapStar-dr17-2M17075252+5737141.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M08573939-4240181.fits to data/test/apogee/aspcapStar-dr17-2M08573939-4240181.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05410227+5542201.fits to data/test/apogee/aspcapStar-dr17-2M05410227+5542201.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M12385071-2708504.fits to data/test/apogee/aspcapStar-dr17-2M12385071-2708504.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17500491-2154366.fits to data/test/apogee/aspcapStar-dr17-2M17500491-2154366.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M01401741+3614126.fits to data/test/apogee/aspcapStar-dr17-2M01401741+3614126.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M13124017+2842475.fits to data/test/apogee/aspcapStar-dr17-2M13124017+2842475.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M14595295+4022578.fits to data/test/apogee/aspcapStar-dr17-2M14595295+4022578.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M15562522+2620590.fits to data/test/apogee/aspcapStar-dr17-2M15562522+2620590.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M07581541+0558368.fits to data/test/apogee/aspcapStar-dr17-2M07581541+0558368.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19344508+3847416.fits to data/test/apogee/aspcapStar-dr17-2M19344508+3847416.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M12402012+3807522.fits to data/test/apogee/aspcapStar-dr17-2M12402012+3807522.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M13492329+2339186.fits to data/test/apogee/aspcapStar-dr17-2M13492329+2339186.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19175138-2846166.fits to data/test/apogee/aspcapStar-dr17-2M19175138-2846166.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05431375-5836113.fits to data/test/apogee/aspcapStar-dr17-2M05431375-5836113.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05260532+4407559.fits to data/test/apogee/aspcapStar-dr17-2M05260532+4407559.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M18465697-2554021.fits to data/test/apogee/aspcapStar-dr17-2M18465697-2554021.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M12075671-0039375.fits to data/test/apogee/aspcapStar-dr17-2M12075671-0039375.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M22153464+1155057.fits to data/test/apogee/aspcapStar-dr17-2M22153464+1155057.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M13581158+5553336.fits to data/test/apogee/aspcapStar-dr17-2M13581158+5553336.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M18525157+4352140.fits to data/test/apogee/aspcapStar-dr17-2M18525157+4352140.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M02155601+4207259.fits to data/test/apogee/aspcapStar-dr17-2M02155601+4207259.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19243209+0057473.fits to data/test/apogee/aspcapStar-dr17-2M19243209+0057473.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04323024-6922545.fits to data/test/apogee/aspcapStar-dr17-2M04323024-6922545.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17480322-0525126.fits to data/test/apogee/aspcapStar-dr17-2M17480322-0525126.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04504667-6111363.fits to data/test/apogee/aspcapStar-dr17-2M04504667-6111363.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17182605-2504218.fits to data/test/apogee/aspcapStar-dr17-2M17182605-2504218.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03485007+2106560.fits to data/test/apogee/aspcapStar-dr17-2M03485007+2106560.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M20563947+3912204.fits to data/test/apogee/aspcapStar-dr17-2M20563947+3912204.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M16425315+6750349.fits to data/test/apogee/aspcapStar-dr17-2M16425315+6750349.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06050277-5312470.fits to data/test/apogee/aspcapStar-dr17-2M06050277-5312470.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M15501554-4946298.fits to data/test/apogee/aspcapStar-dr17-2M15501554-4946298.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19284442+4855424.fits to data/test/apogee/aspcapStar-dr17-2M19284442+4855424.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M07133740-7340140.fits to data/test/apogee/aspcapStar-dr17-2M07133740-7340140.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19100307-2145436.fits to data/test/apogee/aspcapStar-dr17-2M19100307-2145436.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03520414+6745119.fits to data/test/apogee/aspcapStar-dr17-2M03520414+6745119.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M13332813+4009254.fits to data/test/apogee/aspcapStar-dr17-2M13332813+4009254.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05291926+4418009.fits to data/test/apogee/aspcapStar-dr17-2M05291926+4418009.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M00331701+6334575.fits to data/test/apogee/aspcapStar-dr17-2M00331701+6334575.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M18303934+0034277.fits to data/test/apogee/aspcapStar-dr17-2M18303934+0034277.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M01012035+0210349.fits to data/test/apogee/aspcapStar-dr17-2M01012035+0210349.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M13430212+3801492.fits to data/test/apogee/aspcapStar-dr17-2M13430212+3801492.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19525961+4829298.fits to data/test/apogee/aspcapStar-dr17-2M19525961+4829298.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M14561285+0149246.fits to data/test/apogee/aspcapStar-dr17-2M14561285+0149246.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M14053552+3922028.fits to data/test/apogee/aspcapStar-dr17-2M14053552+3922028.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M18544616+1624124.fits to data/test/apogee/aspcapStar-dr17-2M18544616+1624124.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04294215+2522226.fits to data/test/apogee/aspcapStar-dr17-2M04294215+2522226.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M20352509-0512363.fits to data/test/apogee/aspcapStar-dr17-2M20352509-0512363.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03514499-7007406.fits to data/test/apogee/aspcapStar-dr17-2M03514499-7007406.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M02290142+4722271.fits to data/test/apogee/aspcapStar-dr17-2M02290142+4722271.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17555362-2833564.fits to data/test/apogee/aspcapStar-dr17-2M17555362-2833564.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M20385293+4108525.fits to data/test/apogee/aspcapStar-dr17-2M20385293+4108525.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03480185+1713025.fits to data/test/apogee/aspcapStar-dr17-2M03480185+1713025.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05000128+2049043.fits to data/test/apogee/aspcapStar-dr17-2M05000128+2049043.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M10001107+4226122.fits to data/test/apogee/aspcapStar-dr17-2M10001107+4226122.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05581330-5750364.fits to data/test/apogee/aspcapStar-dr17-2M05581330-5750364.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04231182-6412369.fits to data/test/apogee/aspcapStar-dr17-2M04231182-6412369.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19195298+0224505.fits to data/test/apogee/aspcapStar-dr17-2M19195298+0224505.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M16080097-3738523.fits to data/test/apogee/aspcapStar-dr17-2M16080097-3738523.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03071654-7653229.fits to data/test/apogee/aspcapStar-dr17-2M03071654-7653229.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M18135774+0556266.fits to data/test/apogee/aspcapStar-dr17-2M18135774+0556266.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M18500839-3100398.fits to data/test/apogee/aspcapStar-dr17-2M18500839-3100398.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M13305634+2427334.fits to data/test/apogee/aspcapStar-dr17-2M13305634+2427334.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06411855-5138127.fits to data/test/apogee/aspcapStar-dr17-2M06411855-5138127.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17484211-0641120.fits to data/test/apogee/aspcapStar-dr17-2M17484211-0641120.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M00421408+3934099.fits to data/test/apogee/aspcapStar-dr17-2M00421408+3934099.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M20243348+5823369.fits to data/test/apogee/aspcapStar-dr17-2M20243348+5823369.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M00213304+5612258.fits to data/test/apogee/aspcapStar-dr17-2M00213304+5612258.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06503645-6826441.fits to data/test/apogee/aspcapStar-dr17-2M06503645-6826441.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06572628+1729402.fits to data/test/apogee/aspcapStar-dr17-2M06572628+1729402.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M07015087-6752416.fits to data/test/apogee/aspcapStar-dr17-2M07015087-6752416.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-AP17345171-3016007.fits to data/test/apogee/aspcapStar-dr17-AP17345171-3016007.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03420866+7909094.fits to data/test/apogee/aspcapStar-dr17-2M03420866+7909094.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M02243974+5722167.fits to data/test/apogee/aspcapStar-dr17-2M02243974+5722167.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M02345825+6121161.fits to data/test/apogee/aspcapStar-dr17-2M02345825+6121161.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M09375643+3549349.fits to data/test/apogee/aspcapStar-dr17-2M09375643+3549349.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03123511-0645260.fits to data/test/apogee/aspcapStar-dr17-2M03123511-0645260.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M20055210+6951337.fits to data/test/apogee/aspcapStar-dr17-2M20055210+6951337.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17392639-3357106.fits to data/test/apogee/aspcapStar-dr17-2M17392639-3357106.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-AP17412999-2534361.fits to data/test/apogee/aspcapStar-dr17-AP17412999-2534361.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19571127+4044440.fits to data/test/apogee/aspcapStar-dr17-2M19571127+4044440.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M09121229+2745423.fits to data/test/apogee/aspcapStar-dr17-2M09121229+2745423.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M00132947+6253403.fits to data/test/apogee/aspcapStar-dr17-2M00132947+6253403.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M08195508+4840583.fits to data/test/apogee/aspcapStar-dr17-2M08195508+4840583.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M14533978+4816197.fits to data/test/apogee/aspcapStar-dr17-2M14533978+4816197.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06053834-6934556.fits to data/test/apogee/aspcapStar-dr17-2M06053834-6934556.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M08104335+2036536.fits to data/test/apogee/aspcapStar-dr17-2M08104335+2036536.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M13390511+4247286.fits to data/test/apogee/aspcapStar-dr17-2M13390511+4247286.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M15352417+2927585.fits to data/test/apogee/aspcapStar-dr17-2M15352417+2927585.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M00243926-7735213.fits to data/test/apogee/aspcapStar-dr17-2M00243926-7735213.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-AP18023919-2619383.fits to data/test/apogee/aspcapStar-dr17-AP18023919-2619383.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M08404826+4326224.fits to data/test/apogee/aspcapStar-dr17-2M08404826+4326224.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M09145053-4825463.fits to data/test/apogee/aspcapStar-dr17-2M09145053-4825463.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03341121+5127515.fits to data/test/apogee/aspcapStar-dr17-2M03341121+5127515.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M16514297+4621577.fits to data/test/apogee/aspcapStar-dr17-2M16514297+4621577.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03223780+4841305.fits to data/test/apogee/aspcapStar-dr17-2M03223780+4841305.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M02390157-3436488.fits to data/test/apogee/aspcapStar-dr17-2M02390157-3436488.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05242632-6728483.fits to data/test/apogee/aspcapStar-dr17-2M05242632-6728483.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M15155829+2739226.fits to data/test/apogee/aspcapStar-dr17-2M15155829+2739226.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19332506+2501586.fits to data/test/apogee/aspcapStar-dr17-2M19332506+2501586.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M20521941+3537522.fits to data/test/apogee/aspcapStar-dr17-2M20521941+3537522.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M20252105+5241006.fits to data/test/apogee/aspcapStar-dr17-2M20252105+5241006.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M09513784+0037156.fits to data/test/apogee/aspcapStar-dr17-2M09513784+0037156.fits
# Files copied: 200

# %%
import os
import shutil
from astropy.io import fits

# Paths
fits_file_path = 'data/test/combined.fits'
source_dir = '../../../projects/k-pop/spectra/apogee/dr17'
dest_dir = 'data/test/apogee/'

# Ensure the destination directory exists
os.makedirs(dest_dir, exist_ok=True)

# Read the existing APOGEE_IDs from the combined.fits file to ensure they are not copied
existing_ids = set()
with fits.open(fits_file_path) as hdul:
    if 'APOGEE_ID' in hdul[1].columns.names:
        existing_ids = set(hdul[1].data['APOGEE_ID'])

# Initialize a counter for the number of files copied
file_count = 0

# Iterate through potential APOGEE_IDs and copy the first matching file
for root, dirs, files in os.walk(source_dir):
    for file in files:
        if file.endswith('.fits'):
            apogee_id = file.split('-')[-1].split('.')[0]  # Extract the APOGEE_ID from the filename
            # Check if the APOGEE_ID is not in the existing IDs and we have not reached 200 files yet
            if apogee_id not in existing_ids and file_count < 200:
                src_file_path = os.path.join(root, file)
                dest_file_path = os.path.join(dest_dir, file)  # Use original filename in the destination
                shutil.copy(src_file_path, dest_file_path)
                print(f'Copied: {src_file_path} to {dest_file_path}')
                file_count += 1
                existing_ids.add(apogee_id)  # Ensure no further files with this APOGEE_ID are copied
                # Break if 200 files have been copied
                if file_count >= 200:
                    break
    if file_count >= 200:
        break

print(f"Files copied: {file_count}")
# Out:
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06483509-6520109.fits to data/test/apogee/aspcapStar-dr17-2M06483509-6520109.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19455033+3934254.fits to data/test/apogee/aspcapStar-dr17-2M19455033+3934254.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05364343-7600459.fits to data/test/apogee/aspcapStar-dr17-2M05364343-7600459.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M16170533+4207595.fits to data/test/apogee/aspcapStar-dr17-2M16170533+4207595.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M02333009+6128540.fits to data/test/apogee/aspcapStar-dr17-2M02333009+6128540.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-AP00430216+4119487.fits to data/test/apogee/aspcapStar-dr17-AP00430216+4119487.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17383598-2520437.fits to data/test/apogee/aspcapStar-dr17-2M17383598-2520437.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05561286-6458573.fits to data/test/apogee/aspcapStar-dr17-2M05561286-6458573.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M08364426+4343497.fits to data/test/apogee/aspcapStar-dr17-2M08364426+4343497.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M08452451+1222564.fits to data/test/apogee/aspcapStar-dr17-2M08452451+1222564.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M22131053+6237374.fits to data/test/apogee/aspcapStar-dr17-2M22131053+6237374.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M12585388+2630367.fits to data/test/apogee/aspcapStar-dr17-2M12585388+2630367.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03291132+3122570.fits to data/test/apogee/aspcapStar-dr17-2M03291132+3122570.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M16480240+3241036.fits to data/test/apogee/aspcapStar-dr17-2M16480240+3241036.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03130530+4915243.fits to data/test/apogee/aspcapStar-dr17-2M03130530+4915243.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19050661-2058554.fits to data/test/apogee/aspcapStar-dr17-2M19050661-2058554.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03400383+4553266.fits to data/test/apogee/aspcapStar-dr17-2M03400383+4553266.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06321228-7049012.fits to data/test/apogee/aspcapStar-dr17-2M06321228-7049012.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06452898-0500022.fits to data/test/apogee/aspcapStar-dr17-2M06452898-0500022.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M11514811-0030066.fits to data/test/apogee/aspcapStar-dr17-2M11514811-0030066.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M07305670-1159092.fits to data/test/apogee/aspcapStar-dr17-2M07305670-1159092.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06304416-7516481.fits to data/test/apogee/aspcapStar-dr17-2M06304416-7516481.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17535668-1858598.fits to data/test/apogee/aspcapStar-dr17-2M17535668-1858598.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M02222441+4216597.fits to data/test/apogee/aspcapStar-dr17-2M02222441+4216597.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19122005-0029329.fits to data/test/apogee/aspcapStar-dr17-2M19122005-0029329.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M07503562-6440272.fits to data/test/apogee/aspcapStar-dr17-2M07503562-6440272.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M16235301-5527409.fits to data/test/apogee/aspcapStar-dr17-2M16235301-5527409.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M16192925+4349513.fits to data/test/apogee/aspcapStar-dr17-2M16192925+4349513.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M12181260+3654369.fits to data/test/apogee/aspcapStar-dr17-2M12181260+3654369.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M13110694-0223452.fits to data/test/apogee/aspcapStar-dr17-2M13110694-0223452.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19262371+4848086.fits to data/test/apogee/aspcapStar-dr17-2M19262371+4848086.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M10211451+4635128.fits to data/test/apogee/aspcapStar-dr17-2M10211451+4635128.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M18034076-3128489.fits to data/test/apogee/aspcapStar-dr17-2M18034076-3128489.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06074222-7738008.fits to data/test/apogee/aspcapStar-dr17-2M06074222-7738008.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M09401222-3708485.fits to data/test/apogee/aspcapStar-dr17-2M09401222-3708485.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19581477+1839405.fits to data/test/apogee/aspcapStar-dr17-2M19581477+1839405.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M09071941+2741594.fits to data/test/apogee/aspcapStar-dr17-2M09071941+2741594.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17354172-3303389.fits to data/test/apogee/aspcapStar-dr17-2M17354172-3303389.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M13182212+2929075.fits to data/test/apogee/aspcapStar-dr17-2M13182212+2929075.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19121817+2636189.fits to data/test/apogee/aspcapStar-dr17-2M19121817+2636189.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M10342593+0509350.fits to data/test/apogee/aspcapStar-dr17-2M10342593+0509350.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03114538+0014213.fits to data/test/apogee/aspcapStar-dr17-2M03114538+0014213.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M11313755+5248565.fits to data/test/apogee/aspcapStar-dr17-2M11313755+5248565.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19285898+4617550.fits to data/test/apogee/aspcapStar-dr17-2M19285898+4617550.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M01300904+0646314.fits to data/test/apogee/aspcapStar-dr17-2M01300904+0646314.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17000061-2232451.fits to data/test/apogee/aspcapStar-dr17-2M17000061-2232451.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03322024+4557215.fits to data/test/apogee/aspcapStar-dr17-2M03322024+4557215.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M18311104+0241471.fits to data/test/apogee/aspcapStar-dr17-2M18311104+0241471.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06473318-7601465.fits to data/test/apogee/aspcapStar-dr17-2M06473318-7601465.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M01050392+0545419.fits to data/test/apogee/aspcapStar-dr17-2M01050392+0545419.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03380895+1952075.fits to data/test/apogee/aspcapStar-dr17-2M03380895+1952075.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M08070169+5132179.fits to data/test/apogee/aspcapStar-dr17-2M08070169+5132179.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M21284781+5836227.fits to data/test/apogee/aspcapStar-dr17-2M21284781+5836227.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04073684-6745254.fits to data/test/apogee/aspcapStar-dr17-2M04073684-6745254.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M20005939+4442514.fits to data/test/apogee/aspcapStar-dr17-2M20005939+4442514.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M16063154-2335468.fits to data/test/apogee/aspcapStar-dr17-2M16063154-2335468.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M16544215+2021505.fits to data/test/apogee/aspcapStar-dr17-2M16544215+2021505.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19204356+3747019.fits to data/test/apogee/aspcapStar-dr17-2M19204356+3747019.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04122011-6600474.fits to data/test/apogee/aspcapStar-dr17-2M04122011-6600474.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04113035+2739395.fits to data/test/apogee/aspcapStar-dr17-2M04113035+2739395.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M15135297+4121478.fits to data/test/apogee/aspcapStar-dr17-2M15135297+4121478.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03183527+0842049.fits to data/test/apogee/aspcapStar-dr17-2M03183527+0842049.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M09451691+3849236.fits to data/test/apogee/aspcapStar-dr17-2M09451691+3849236.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M14135462+4118182.fits to data/test/apogee/aspcapStar-dr17-2M14135462+4118182.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-AP18090653-3119243.fits to data/test/apogee/aspcapStar-dr17-AP18090653-3119243.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04584489-7059111.fits to data/test/apogee/aspcapStar-dr17-2M04584489-7059111.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M01442843+3612543.fits to data/test/apogee/aspcapStar-dr17-2M01442843+3612543.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M07015373-6308321.fits to data/test/apogee/aspcapStar-dr17-2M07015373-6308321.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M18005522-3030153.fits to data/test/apogee/aspcapStar-dr17-2M18005522-3030153.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17431967-2228435.fits to data/test/apogee/aspcapStar-dr17-2M17431967-2228435.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M22005422-1304309.fits to data/test/apogee/aspcapStar-dr17-2M22005422-1304309.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M08274256+4249501.fits to data/test/apogee/aspcapStar-dr17-2M08274256+4249501.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17594058+6157509.fits to data/test/apogee/aspcapStar-dr17-2M17594058+6157509.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M12123163+4602119.fits to data/test/apogee/aspcapStar-dr17-2M12123163+4602119.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M15191925-4157410.fits to data/test/apogee/aspcapStar-dr17-2M15191925-4157410.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M20232983+1641270.fits to data/test/apogee/aspcapStar-dr17-2M20232983+1641270.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M07374325+4641267.fits to data/test/apogee/aspcapStar-dr17-2M07374325+4641267.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M15580991-2244333.fits to data/test/apogee/aspcapStar-dr17-2M15580991-2244333.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04570669+7219354.fits to data/test/apogee/aspcapStar-dr17-2M04570669+7219354.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19235074+6533399.fits to data/test/apogee/aspcapStar-dr17-2M19235074+6533399.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03544024+2032232.fits to data/test/apogee/aspcapStar-dr17-2M03544024+2032232.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05410634-0810006.fits to data/test/apogee/aspcapStar-dr17-2M05410634-0810006.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M01182926+0701157.fits to data/test/apogee/aspcapStar-dr17-2M01182926+0701157.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M09045109+3229266.fits to data/test/apogee/aspcapStar-dr17-2M09045109+3229266.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05143322+4538260.fits to data/test/apogee/aspcapStar-dr17-2M05143322+4538260.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03293013+6257119.fits to data/test/apogee/aspcapStar-dr17-2M03293013+6257119.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19175572+4424496.fits to data/test/apogee/aspcapStar-dr17-2M19175572+4424496.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17281750-2902266.fits to data/test/apogee/aspcapStar-dr17-2M17281750-2902266.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M02415044-1157536.fits to data/test/apogee/aspcapStar-dr17-2M02415044-1157536.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-AP17523977-2837540.fits to data/test/apogee/aspcapStar-dr17-AP17523977-2837540.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05530209-7116128.fits to data/test/apogee/aspcapStar-dr17-2M05530209-7116128.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M08045911-6900365.fits to data/test/apogee/aspcapStar-dr17-2M08045911-6900365.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04465997+2434299.fits to data/test/apogee/aspcapStar-dr17-2M04465997+2434299.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M10322555+4420439.fits to data/test/apogee/aspcapStar-dr17-2M10322555+4420439.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19034794-1006347.fits to data/test/apogee/aspcapStar-dr17-2M19034794-1006347.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M10482685+1620452.fits to data/test/apogee/aspcapStar-dr17-2M10482685+1620452.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M08183179+3838281.fits to data/test/apogee/aspcapStar-dr17-2M08183179+3838281.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17075252+5737141.fits to data/test/apogee/aspcapStar-dr17-2M17075252+5737141.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M08573939-4240181.fits to data/test/apogee/aspcapStar-dr17-2M08573939-4240181.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05410227+5542201.fits to data/test/apogee/aspcapStar-dr17-2M05410227+5542201.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M12385071-2708504.fits to data/test/apogee/aspcapStar-dr17-2M12385071-2708504.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17500491-2154366.fits to data/test/apogee/aspcapStar-dr17-2M17500491-2154366.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M01401741+3614126.fits to data/test/apogee/aspcapStar-dr17-2M01401741+3614126.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M13124017+2842475.fits to data/test/apogee/aspcapStar-dr17-2M13124017+2842475.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M14595295+4022578.fits to data/test/apogee/aspcapStar-dr17-2M14595295+4022578.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M15562522+2620590.fits to data/test/apogee/aspcapStar-dr17-2M15562522+2620590.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M07581541+0558368.fits to data/test/apogee/aspcapStar-dr17-2M07581541+0558368.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19344508+3847416.fits to data/test/apogee/aspcapStar-dr17-2M19344508+3847416.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M12402012+3807522.fits to data/test/apogee/aspcapStar-dr17-2M12402012+3807522.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M13492329+2339186.fits to data/test/apogee/aspcapStar-dr17-2M13492329+2339186.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19175138-2846166.fits to data/test/apogee/aspcapStar-dr17-2M19175138-2846166.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05431375-5836113.fits to data/test/apogee/aspcapStar-dr17-2M05431375-5836113.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05260532+4407559.fits to data/test/apogee/aspcapStar-dr17-2M05260532+4407559.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M18465697-2554021.fits to data/test/apogee/aspcapStar-dr17-2M18465697-2554021.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M12075671-0039375.fits to data/test/apogee/aspcapStar-dr17-2M12075671-0039375.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M22153464+1155057.fits to data/test/apogee/aspcapStar-dr17-2M22153464+1155057.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M13581158+5553336.fits to data/test/apogee/aspcapStar-dr17-2M13581158+5553336.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M18525157+4352140.fits to data/test/apogee/aspcapStar-dr17-2M18525157+4352140.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M02155601+4207259.fits to data/test/apogee/aspcapStar-dr17-2M02155601+4207259.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19243209+0057473.fits to data/test/apogee/aspcapStar-dr17-2M19243209+0057473.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04323024-6922545.fits to data/test/apogee/aspcapStar-dr17-2M04323024-6922545.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17480322-0525126.fits to data/test/apogee/aspcapStar-dr17-2M17480322-0525126.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04504667-6111363.fits to data/test/apogee/aspcapStar-dr17-2M04504667-6111363.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17182605-2504218.fits to data/test/apogee/aspcapStar-dr17-2M17182605-2504218.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03485007+2106560.fits to data/test/apogee/aspcapStar-dr17-2M03485007+2106560.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M20563947+3912204.fits to data/test/apogee/aspcapStar-dr17-2M20563947+3912204.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M16425315+6750349.fits to data/test/apogee/aspcapStar-dr17-2M16425315+6750349.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06050277-5312470.fits to data/test/apogee/aspcapStar-dr17-2M06050277-5312470.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M15501554-4946298.fits to data/test/apogee/aspcapStar-dr17-2M15501554-4946298.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19284442+4855424.fits to data/test/apogee/aspcapStar-dr17-2M19284442+4855424.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M07133740-7340140.fits to data/test/apogee/aspcapStar-dr17-2M07133740-7340140.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19100307-2145436.fits to data/test/apogee/aspcapStar-dr17-2M19100307-2145436.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03520414+6745119.fits to data/test/apogee/aspcapStar-dr17-2M03520414+6745119.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M13332813+4009254.fits to data/test/apogee/aspcapStar-dr17-2M13332813+4009254.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05291926+4418009.fits to data/test/apogee/aspcapStar-dr17-2M05291926+4418009.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M00331701+6334575.fits to data/test/apogee/aspcapStar-dr17-2M00331701+6334575.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M18303934+0034277.fits to data/test/apogee/aspcapStar-dr17-2M18303934+0034277.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M01012035+0210349.fits to data/test/apogee/aspcapStar-dr17-2M01012035+0210349.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M13430212+3801492.fits to data/test/apogee/aspcapStar-dr17-2M13430212+3801492.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19525961+4829298.fits to data/test/apogee/aspcapStar-dr17-2M19525961+4829298.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M14561285+0149246.fits to data/test/apogee/aspcapStar-dr17-2M14561285+0149246.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M14053552+3922028.fits to data/test/apogee/aspcapStar-dr17-2M14053552+3922028.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M18544616+1624124.fits to data/test/apogee/aspcapStar-dr17-2M18544616+1624124.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04294215+2522226.fits to data/test/apogee/aspcapStar-dr17-2M04294215+2522226.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M20352509-0512363.fits to data/test/apogee/aspcapStar-dr17-2M20352509-0512363.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03514499-7007406.fits to data/test/apogee/aspcapStar-dr17-2M03514499-7007406.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M02290142+4722271.fits to data/test/apogee/aspcapStar-dr17-2M02290142+4722271.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17555362-2833564.fits to data/test/apogee/aspcapStar-dr17-2M17555362-2833564.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M20385293+4108525.fits to data/test/apogee/aspcapStar-dr17-2M20385293+4108525.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03480185+1713025.fits to data/test/apogee/aspcapStar-dr17-2M03480185+1713025.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05000128+2049043.fits to data/test/apogee/aspcapStar-dr17-2M05000128+2049043.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M10001107+4226122.fits to data/test/apogee/aspcapStar-dr17-2M10001107+4226122.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05581330-5750364.fits to data/test/apogee/aspcapStar-dr17-2M05581330-5750364.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04231182-6412369.fits to data/test/apogee/aspcapStar-dr17-2M04231182-6412369.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19195298+0224505.fits to data/test/apogee/aspcapStar-dr17-2M19195298+0224505.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M16080097-3738523.fits to data/test/apogee/aspcapStar-dr17-2M16080097-3738523.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03071654-7653229.fits to data/test/apogee/aspcapStar-dr17-2M03071654-7653229.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M18135774+0556266.fits to data/test/apogee/aspcapStar-dr17-2M18135774+0556266.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M18500839-3100398.fits to data/test/apogee/aspcapStar-dr17-2M18500839-3100398.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M13305634+2427334.fits to data/test/apogee/aspcapStar-dr17-2M13305634+2427334.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06411855-5138127.fits to data/test/apogee/aspcapStar-dr17-2M06411855-5138127.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17484211-0641120.fits to data/test/apogee/aspcapStar-dr17-2M17484211-0641120.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M00421408+3934099.fits to data/test/apogee/aspcapStar-dr17-2M00421408+3934099.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M20243348+5823369.fits to data/test/apogee/aspcapStar-dr17-2M20243348+5823369.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M00213304+5612258.fits to data/test/apogee/aspcapStar-dr17-2M00213304+5612258.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06503645-6826441.fits to data/test/apogee/aspcapStar-dr17-2M06503645-6826441.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06572628+1729402.fits to data/test/apogee/aspcapStar-dr17-2M06572628+1729402.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M07015087-6752416.fits to data/test/apogee/aspcapStar-dr17-2M07015087-6752416.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-AP17345171-3016007.fits to data/test/apogee/aspcapStar-dr17-AP17345171-3016007.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03420866+7909094.fits to data/test/apogee/aspcapStar-dr17-2M03420866+7909094.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M02243974+5722167.fits to data/test/apogee/aspcapStar-dr17-2M02243974+5722167.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M02345825+6121161.fits to data/test/apogee/aspcapStar-dr17-2M02345825+6121161.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M09375643+3549349.fits to data/test/apogee/aspcapStar-dr17-2M09375643+3549349.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03123511-0645260.fits to data/test/apogee/aspcapStar-dr17-2M03123511-0645260.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M20055210+6951337.fits to data/test/apogee/aspcapStar-dr17-2M20055210+6951337.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M17392639-3357106.fits to data/test/apogee/aspcapStar-dr17-2M17392639-3357106.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-AP17412999-2534361.fits to data/test/apogee/aspcapStar-dr17-AP17412999-2534361.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19571127+4044440.fits to data/test/apogee/aspcapStar-dr17-2M19571127+4044440.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M09121229+2745423.fits to data/test/apogee/aspcapStar-dr17-2M09121229+2745423.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M00132947+6253403.fits to data/test/apogee/aspcapStar-dr17-2M00132947+6253403.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M08195508+4840583.fits to data/test/apogee/aspcapStar-dr17-2M08195508+4840583.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M14533978+4816197.fits to data/test/apogee/aspcapStar-dr17-2M14533978+4816197.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06053834-6934556.fits to data/test/apogee/aspcapStar-dr17-2M06053834-6934556.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M08104335+2036536.fits to data/test/apogee/aspcapStar-dr17-2M08104335+2036536.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M13390511+4247286.fits to data/test/apogee/aspcapStar-dr17-2M13390511+4247286.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M15352417+2927585.fits to data/test/apogee/aspcapStar-dr17-2M15352417+2927585.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M00243926-7735213.fits to data/test/apogee/aspcapStar-dr17-2M00243926-7735213.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-AP18023919-2619383.fits to data/test/apogee/aspcapStar-dr17-AP18023919-2619383.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M08404826+4326224.fits to data/test/apogee/aspcapStar-dr17-2M08404826+4326224.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M09145053-4825463.fits to data/test/apogee/aspcapStar-dr17-2M09145053-4825463.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03341121+5127515.fits to data/test/apogee/aspcapStar-dr17-2M03341121+5127515.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M16514297+4621577.fits to data/test/apogee/aspcapStar-dr17-2M16514297+4621577.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M03223780+4841305.fits to data/test/apogee/aspcapStar-dr17-2M03223780+4841305.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M02390157-3436488.fits to data/test/apogee/aspcapStar-dr17-2M02390157-3436488.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05242632-6728483.fits to data/test/apogee/aspcapStar-dr17-2M05242632-6728483.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M15155829+2739226.fits to data/test/apogee/aspcapStar-dr17-2M15155829+2739226.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M19332506+2501586.fits to data/test/apogee/aspcapStar-dr17-2M19332506+2501586.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M20521941+3537522.fits to data/test/apogee/aspcapStar-dr17-2M20521941+3537522.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M20252105+5241006.fits to data/test/apogee/aspcapStar-dr17-2M20252105+5241006.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M09513784+0037156.fits to data/test/apogee/aspcapStar-dr17-2M09513784+0037156.fits
# Files copied: 200
