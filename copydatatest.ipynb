# %%
from astropy.io import fits

# Path to your FITS file
# fits_file_path = '../../../projects/k-pop/catalogues/galahdr3-apogeedr17.fits'
fits_file_path = 'data/test/combined.fits'
# Open the FITS file
with fits.open(fits_file_path) as hdul:
    # Access the first extension (HDU 1) which contains the table
    data = hdul[1].data
    
    # Extract the 'APOGEE_ID' and 'sobject_id' columns
    apogee_ids = data['APOGEE_ID']
    galah_ids = data['sobject_id']
    # print(data)
    # Print the 'APOGEE_ID' and 'sobject_id' data for the first five entries
    print("Matched IDs:")
    for i in range(3):  # Ensure we don't go out of range if fewer than 5 entries
        print(f"APOGEE ID: {apogee_ids[i]}, GALAH ID: {galah_ids[i]}")

# This script will display the first five pairs of APOGEE and GALAH identifiers.
# Out:
# Matched IDs:
# APOGEE ID: 2M04394779-5753520, GALAH ID: 131118002401015
# APOGEE ID: 2M04390586-5752435, GALAH ID: 131118002401016
# APOGEE ID: 2M04372258-5755132, GALAH ID: 131118002401023

# %%
from astropy.io import fits
import pandas as pd

# Load the FITS file
fits_path = '../../../projects/k-pop/catalogues/galahdr3-apogeedr17.fits'  # Replace with the path to your FITS file
with fits.open(fits_path) as hdul:
    data = hdul[1].data  # Assuming the data of interest is in the first extension

# Convert to a pandas DataFrame
df = pd.DataFrame(data)

# Print the first 5 rows of the DataFrame
print(df.head())
# Out:
#             star_id       sobject_id           APOGEE_ID   GAIAEDR3_SOURCE_ID  \
# 0  04394779-5753520  131118002401015  2M04394779-5753520  4774350796594075008
# 1  04390586-5752435  131118002401016  2M04390586-5752435  4774349937600609664
# 2  04372258-5755132  131118002401023  2M04372258-5755132  4774340797910201984
# 3  04391862-5802387  131118002401025  2M04391862-5802387  4774324614473456640
# 4  04384845-5813280  131118002401038  2M04384845-5813280  4774315852740197376
#
#           RA        DEC
# 0  69.949141 -57.897781
# 1  69.774443 -57.878754
# 2  69.344086 -57.920361
# 3  69.827605 -58.044109
# 4  69.701901 -58.224445

# %%
from astropy.io import fits
import pandas as pd

# Load the FITS file
fits_path = '../../../projects/k-pop/spectra/galah/dr3/1902250027013731.fits'  # Replace with the path to your FITS file
with fits.open(fits_path) as hdul:
    data = hdul[1].data  # Assuming the data of interest is in the first extension

# Convert to a pandas DataFrame
df = pd.DataFrame(data)

# Print the first 5 rows of the DataFrame
print(df.head())
# Out:
#           0
# 0  0.052054
# 1  0.050679
# 2  0.050785
# 3  0.050299
# 4  0.048695

# %%
from astropy.io import fits
from astropy.table import Table

# Path to the original and the new FITS file
original_fits_path = '../../../projects/k-pop/catalogues/galahdr3-apogeedr17.fits'
new_fits_path = 'data/test/combined.fits'

# Open the original FITS file
with fits.open(original_fits_path) as hdul:
    # Access the data in the first extension (HDU 1)
    data = hdul[1].data
    
    # Convert FITS data to an Astropy Table for easier manipulation
    table = Table(data)
    
    # Copy the first five rows
    new_table = table[:100]

    # Create a new HDU from the table
    hdu = fits.BinTableHDU(new_table)

    # Write the new FITS file with only the first five entries
    hdu.writeto(new_fits_path, overwrite=True)

print(f"Created new FITS file with  entries at {new_fits_path}")
# Out:
# Created new FITS file with  entries at data/test/combined.fits

# %%
import os
import shutil
from astropy.io import fits

# Path to the original FITS file
fits_file_path = 'data/test/combined.fits'
# Directory containing the APOGEE FITS files
source_dir = '../../../projects/k-pop/spectra/apogee/dr17'
# Destination directory
dest_dir = 'data/test/apogee/'

# Ensure the destination directory exists
os.makedirs(dest_dir, exist_ok=True)

# Open the FITS file and read APOGEE_IDs
with fits.open(fits_file_path) as hdul:
    apogee_ids = hdul[1].data['APOGEE_ID']

# Copy the first five corresponding FITS files
for apogee_id in apogee_ids:
    src_file_path = os.path.join(source_dir, f'aspcapStar-dr17-{apogee_id.strip()}.fits')
    dest_file_path = os.path.join(dest_dir, f'aspcapStar-dr17-{apogee_id.strip()}.fits')
    # Check if source file exists before copying
    if os.path.exists(src_file_path):
        shutil.copy(src_file_path, dest_file_path)
        print(f'Copied: {src_file_path} to {dest_file_path}')
    else:
        print(f'Source file not found: {src_file_path}')

print("Files have been copied.")
# Out:
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04394779-5753520.fits to data/test/apogee/aspcapStar-dr17-2M04394779-5753520.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04390586-5752435.fits to data/test/apogee/aspcapStar-dr17-2M04390586-5752435.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04372258-5755132.fits to data/test/apogee/aspcapStar-dr17-2M04372258-5755132.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04391862-5802387.fits to data/test/apogee/aspcapStar-dr17-2M04391862-5802387.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04384845-5813280.fits to data/test/apogee/aspcapStar-dr17-2M04384845-5813280.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04373299-5814393.fits to data/test/apogee/aspcapStar-dr17-2M04373299-5814393.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04362390-5807107.fits to data/test/apogee/aspcapStar-dr17-2M04362390-5807107.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04362311-5825430.fits to data/test/apogee/aspcapStar-dr17-2M04362311-5825430.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04362309-5831586.fits to data/test/apogee/aspcapStar-dr17-2M04362309-5831586.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04361896-5833145.fits to data/test/apogee/aspcapStar-dr17-2M04361896-5833145.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M04361209-5833162.fits to data/test/apogee/aspcapStar-dr17-2M04361209-5833162.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05273949-5752129.fits to data/test/apogee/aspcapStar-dr17-2M05273949-5752129.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05305052-5754076.fits to data/test/apogee/aspcapStar-dr17-2M05305052-5754076.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05300886-5756494.fits to data/test/apogee/aspcapStar-dr17-2M05300886-5756494.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05284808-5759583.fits to data/test/apogee/aspcapStar-dr17-2M05284808-5759583.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05311779-5810048.fits to data/test/apogee/aspcapStar-dr17-2M05311779-5810048.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05315649-5812265.fits to data/test/apogee/aspcapStar-dr17-2M05315649-5812265.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05321481-5814597.fits to data/test/apogee/aspcapStar-dr17-2M05321481-5814597.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05311201-5813034.fits to data/test/apogee/aspcapStar-dr17-2M05311201-5813034.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05284065-5800105.fits to data/test/apogee/aspcapStar-dr17-2M05284065-5800105.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05312655-5823570.fits to data/test/apogee/aspcapStar-dr17-2M05312655-5823570.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05302143-5817378.fits to data/test/apogee/aspcapStar-dr17-2M05302143-5817378.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M05305203-5828066.fits to data/test/apogee/aspcapStar-dr17-2M05305203-5828066.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M
fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06060359-5826429.fits to data/test/apogee/aspcapStar-dr17-2M06060359-5826429.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06084625-5831090.fits to data/test/apogee/aspcapStar-dr17-2M06084625-5831090.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06082161-5818403.fits to data/test/apogee/aspcapStar-dr17-2M06082161-5818403.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06100162-5835400.fits to data/test/apogee/aspcapStar-dr17-2M06100162-5835400.fits
# Copied: ../../../projects/k-pop/spectra/apogee/dr17/aspcapStar-dr17-2M06080111-5759485.fits to data/test/apogee/aspcapStar-dr17-2M06080111-5759485.fits
# Files have been copied.

# %%
import os
import shutil
from astropy.io import fits

# Path to the original FITS file
fits_file_path = 'data/test/combined.fits'
# Directory containing the APOGEE FITS files
source_dir = '../../../projects/k-pop/spectra/galah/dr3'
# Destination directory
dest_dir = 'data/test/galah'

# Ensure the destination directory exists
os.makedirs(dest_dir, exist_ok=True)

# Open the FITS file and read APOGEE_IDs
with fits.open(fits_file_path) as hdul:
    galah_ids = hdul[1].data['sobject_id']

# Copy the first corresponding FITS file that is found
for galah_id in galah_ids:
    file_found = False
    for i in range(1, 10): 
        src_file_path = os.path.join(source_dir, f'{galah_id}{i}.fits')
        dest_file_path = os.path.join(dest_dir, f'{galah_id}.fits')
        if os.path.exists(src_file_path):
            shutil.copy(src_file_path, dest_file_path)
            print(f'Copied: {src_file_path} to {dest_file_path}')
            file_found = True
            break
    if not file_found:
        print(f'No source file found for: {galah_id} with any suffix.')

print("Files have been copied.")
# Out:
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010151.fits to data/test/galah/131118002401015.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010161.fits to data/test/galah/131118002401016.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010231.fits to data/test/galah/131118002401023.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010251.fits to data/test/galah/131118002401025.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010381.fits to data/test/galah/131118002401038.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010461.fits to data/test/galah/131118002401046.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010471.fits to data/test/galah/131118002401047.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010631.fits to data/test/galah/131118002401063.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010661.fits to data/test/galah/131118002401066.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010681.fits to data/test/galah/131118002401068.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180024010691.fits to data/test/galah/131118002401069.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010031.fits to data/test/galah/131118002901003.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010041.fits to data/test/galah/131118002901004.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010091.fits to data/test/galah/131118002901009.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010131.fits to data/test/galah/131118002901013.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010231.fits to data/test/galah/131118002901023.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010261.fits to data/test/galah/131118002901026.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010281.fits to data/test/galah/131118002901028.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010311.fits to data/test/galah/131118002901031.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010351.fits to data/test/galah/131118002901035.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010401.fits to data/test/galah/131118002901040.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010411.fits to data/test/galah/131118002901041.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010461.fits to data/test/galah/131118002901046.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010471.fits to data/test/galah/131118002901047.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010491.fits to data/test/galah/131118002901049.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010521.fits to data/test/galah/131118002901052.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010551.fits to data/test/galah/131118002901055.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010611.fits to data/test/galah/131118002901061.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010641.fits to data/test/galah/131118002901064.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010681.fits to data/test/galah/131118002901068.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010691.fits to data/test/galah/131118002901069.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010771.fits to data/test/galah/131118002901077.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010801.fits to data/test/galah/131118002901080.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010811.fits to data/test/galah/131118002901081.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010841.fits to data/test/galah/131118002901084.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010981.fits to data/test/galah/131118002901098.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029010991.fits to data/test/galah/131118002901099.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029011071.fits to data/test/galah/131118002901107.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029011131.fits to data/test/galah/131118002901113.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029011151.fits to data/test/galah/131118002901115.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029011771.fits to data/test/galah/131118002901177.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029011991.fits to data/test/galah/131118002901199.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012041.fits to data/test/galah/131118002901204.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012061.fits to data/test/galah/131118002901206.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012161.fits to data/test/galah/131118002901216.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012191.fits to data/test/galah/131118002901219.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012381.fits to data/test/galah/131118002901238.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012401.fits to data/test/galah/131118002901240.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012421.fits to data/test/galah/131118002901242.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012521.fits to data/test/galah/131118002901252.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012581.fits to data/test/galah/131118002901258.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012601.fits to data/test/galah/131118002901260.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012651.fits to data/test/galah/131118002901265.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012711.fits to data/test/galah/131118002901271.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012801.fits to data/test/galah/131118002901280.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012931.fits to data/test/galah/131118002901293.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012951.fits to data/test/galah/131118002901295.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029012961.fits to data/test/galah/131118002901296.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013031.fits to data/test/galah/131118002901303.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013041.fits to data/test/galah/131118002901304.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013091.fits to data/test/galah/131118002901309.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013141.fits to data/test/galah/131118002901314.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013161.fits to data/test/galah/131118002901316.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013241.fits to data/test/galah/131118002901324.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013281.fits to data/test/galah/131118002901328.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013351.fits to data/test/galah/131118002901335.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013421.fits to data/test/galah/131118002901342.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013431.fits to data/test/galah/131118002901343.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013451.fits to data/test/galah/131118002901345.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013461.fits to data/test/galah/131118002901346.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013481.fits to data/test/galah/131118002901348.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013551.fits to data/test/galah/131118002901355.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013601.fits to data/test/galah/131118002901360.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013721.fits to data/test/galah/131118002901372.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013741.fits to data/test/galah/131118002901374.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013771.fits to data/test/galah/131118002901377.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180029013881.fits to data/test/galah/131118002901388.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034010431.fits to data/test/galah/131118003401043.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034010701.fits to data/test/galah/131118003401070.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011031.fits to data/test/galah/131118003401103.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011091.fits to data/test/galah/131118003401109.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011141.fits to data/test/galah/131118003401114.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011221.fits to data/test/galah/131118003401122.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011231.fits to data/test/galah/131118003401123.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011281.fits to data/test/galah/131118003401128.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011341.fits to data/test/galah/131118003401134.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011461.fits to data/test/galah/131118003401146.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011531.fits to data/test/galah/131118003401153.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011591.fits to data/test/galah/131118003401159.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011841.fits to data/test/galah/131118003401184.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011901.fits to data/test/galah/131118003401190.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034011971.fits to data/test/galah/131118003401197.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012051.fits to data/test/galah/131118003401205.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012071.fits to data/test/galah/131118003401207.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012311.fits to data/test/galah/131118003401231.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012321.fits to data/test/galah/131118003401232.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012431.fits to data/test/galah/131118003401243.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012561.fits to data/test/galah/131118003401256.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012621.fits to data/test/galah/131118003401262.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1311180034012661.fits to data/test/galah/131118003401266.fits
# Files have been copied.

# %%
import os
import shutil
from astropy.io import fits

# Paths
fits_file_path = 'data/test/combined.fits'
source_dir = '../../../projects/k-pop/spectra/galah/dr3'
dest_dir = 'data/test2/galah'

# Make sure the destination directory exists
os.makedirs(dest_dir, exist_ok=True)

# Read the existing GALAH_IDs from the combined.fits file to ensure they are not copied
with fits.open(fits_file_path) as hdul:
    existing_ids = set(hdul[1].data['sobject_id'])

# Initialize a counter for the number of files copied
file_count = 0

# Iterate through potential GALAH_IDs and copy the first matching file
for root, dirs, files in os.walk(source_dir):
    for file in files:
        if file.endswith('.fits'):
            galah_id = file.split('.')[0][:-1]  # Remove the last character (number) and the extension
            # Check if the GALAH_ID is not in the existing IDs and we have not reached 200 files yet
            if galah_id not in existing_ids and file_count < 200:
                src_file_path = os.path.join(root, file)
                dest_file_path = os.path.join(dest_dir, f'{galah_id}.fits')
                shutil.copy(src_file_path, dest_file_path)
                print(f'Copied: {src_file_path} to {dest_file_path}')
                file_count += 1
                existing_ids.add(galah_id)  # Ensure no further files with this GALAH_ID are copied
                # Break if 200 files have been copied
                if file_count >= 200:
                    break
    if file_count >= 200:
        break

print(f"Files copied: {file_count}")
# Out:
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1603301028013931.fits to data/test2/galah/160330102801393.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1611080016013994.fits to data/test2/galah/161108001601399.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1601060021010974.fits to data/test2/galah/160106002101097.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1705170023012282.fits to data/test2/galah/170517002301228.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1801250019011321.fits to data/test2/galah/180125001901132.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1708300011012011.fits to data/test2/galah/170830001101201.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1604180036012872.fits to data/test2/galah/160418003601287.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1709100046011333.fits to data/test2/galah/170910004601133.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1704140036013384.fits to data/test2/galah/170414003601338.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1708020032011242.fits to data/test2/galah/170802003201124.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1506040034023364.fits to data/test2/galah/150604003402336.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1612100026010604.fits to data/test2/galah/161210002601060.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1801290026012923.fits to data/test2/galah/180129002601292.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1611050041010214.fits to data/test2/galah/161105004101021.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1701140052011452.fits to data/test2/galah/170114005201145.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1502090039012801.fits to data/test2/galah/150209003901280.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1504110046022653.fits to data/test2/galah/150411004602265.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1701050021011434.fits to data/test2/galah/170105002101143.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1408110027011274.fits to data/test2/galah/140811002701127.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1704070057011101.fits to data/test2/galah/170407005701110.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1604150016011291.fits to data/test2/galah/160415001601129.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1605220031012223.fits to data/test2/galah/160522003101222.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1611190028010671.fits to data/test2/galah/161119002801067.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1812250041012952.fits to data/test2/galah/181225004101295.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1704180057011573.fits to data/test2/galah/170418005701157.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1902250042010624.fits to data/test2/galah/190225004201062.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1504110056011111.fits to data/test2/galah/150411005601111.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1707100032012964.fits to data/test2/galah/170710003201296.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1601290042012063.fits to data/test2/galah/160129004201206.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1707120021010614.fits to data/test2/galah/170712002101061.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1806250021013712.fits to data/test2/galah/180625002101371.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1601060021012302.fits to data/test2/galah/160106002101230.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1506020033013024.fits to data/test2/galah/150602003301302.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1812260026013363.fits to data/test2/galah/181226002601336.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1707110040012043.fits to data/test2/galah/170711004001204.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1501050022012714.fits to data/test2/galah/150105002201271.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1408110045010812.fits to data/test2/galah/140811004501081.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1508280027011653.fits to data/test2/galah/150828002701165.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1502090033010893.fits to data/test2/galah/150209003301089.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1312180024011163.fits to data/test2/galah/131218002401116.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1812210016013442.fits to data/test2/galah/181221001601344.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1611040038010583.fits to data/test2/galah/161104003801058.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1709040006010213.fits to data/test2/galah/170904000601021.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1812230025013962.fits to data/test2/galah/181223002501396.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1507050049010141.fits to data/test2/galah/150705004901014.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1604210021010484.fits to data/test2/galah/160421002101048.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1708050021010563.fits to data/test2/galah/170805002101056.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1902120020012424.fits to data/test2/galah/190212002001242.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1712300031011403.fits to data/test2/galah/171230003101140.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1504060018013263.fits to data/test2/galah/150406001801326.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1604180036012892.fits to data/test2/galah/160418003601289.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1604220025013434.fits to data/test2/galah/160422002501343.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1706140026012994.fits to data/test2/galah/170614002601299.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1707130021012131.fits to data/test2/galah/170713002101213.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1708020038012903.fits to data/test2/galah/170802003801290.fits
# Copied: ../../../projects/k-pop/spectra/galah/dr3/1504280031022142.fits to data/test2/galah/150428003102214.fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 29
#      27 src_file_path = os.path.join(root, file)
#      28 dest_file_path = os.path.join(dest_dir, f'{galah_id}.fits')
# ---> 29 shutil.copy(src_file_path, dest_file_path)
#      30 print(f'Copied: {src_file_path} to {dest_file_path}')
#      31 file_count += 1
#
# File /opt/conda/lib/python3.11/shutil.py:431, in copy(src, dst, follow_symlinks)
#     429 if os.path.isdir(dst):
#     430     dst = os.path.join(dst, os.path.basename(src))
# --> 431 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     432 copymode(src, dst, follow_symlinks=follow_symlinks)
#     433 return dst
#
# File /opt/conda/lib/python3.11/shutil.py:269, in copyfile(src, dst, follow_symlinks)
#     267 elif _USE_CP_SENDFILE:
#     268     try:
# --> 269         _fastcopy_sendfile(fsrc, fdst)
#     270         return dst
#     271     except _GiveupOnFastCopy:
#
# File /opt/conda/lib/python3.11/shutil.py:144, in _fastcopy_sendfile(fsrc, fdst)
#     142 while True:
#     143     try:
# --> 144         sent = os.sendfile(outfd, infd, offset, blocksize)
#     145     except OSError as err:
#     146         # ...in oder to have a more informative exception.
#     147         err.filename = fsrc.name
#
# KeyboardInterrupt:

# %%
import os
import shutil
from astropy.io import fits

# Paths
fits_file_path = 'data/test/combined.fits'
source_dir = '../../../projects/k-pop/spectra/apogee/dr17'
dest_dir = 'data/test2/apogee/'

# Ensure the destination directory exists
os.makedirs(dest_dir, exist_ok=True)

# Read the existing APOGEE_IDs from the combined.fits file to ensure they are not copied
existing_ids = set()
with fits.open(fits_file_path) as hdul:
    if 'APOGEE_ID' in hdul[1].columns.names:
        existing_ids = set(hdul[1].data['APOGEE_ID'])

# Initialize a counter for the number of files copied
file_count = 0

# Iterate through potential APOGEE_IDs and copy the first matching file
for root, dirs, files in os.walk(source_dir):
    for file in files:
        if file.endswith('.fits'):
            apogee_id = file.split('-')[-1].split('.')[0]  # Extract the APOGEE_ID from the filename
            # Check if the APOGEE_ID is not in the existing IDs and we have not reached 200 files yet
            if apogee_id not in existing_ids and file_count < 200:
                src_file_path = os.path.join(root, file)
                dest_file_path = os.path.join(dest_dir, file)  # Use original filename in the destination
                shutil.copy(src_file_path, dest_file_path)
                print(f'Copied: {src_file_path} to {dest_file_path}')
                file_count += 1
                existing_ids.add(apogee_id)  # Ensure no further files with this APOGEE_ID are copied
                # Break if 200 files have been copied
                if file_count >= 200:
                    break
    if file_count >= 200:
        break

print(f"Files copied: {file_count}")
